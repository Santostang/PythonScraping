# %% [markdown]
# # 14.3 项目实施

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json

def getjson(loc):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': 0, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

getjson('北京市')
# Out:
# {'status': 0,
#  'message': 'ok',
#  'total': 400,
#  'results': [{'name': '后海公园',
#    'location': {'lat': 39.948473, 'lng': 116.388894},
#    'address': '北京市西城区松树街1号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '西城区',
#    'street_id': '7aea43b721dd95e17d29bda4',
#    'detail': 1,
#    'uid': '7aea43b721dd95e17d29bda4',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.38864586804, 'lat': 39.947822400829},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=7aea43b721dd95e17d29bda4&output=html&source=placeapi_v2',
#     'overall_rating': '4.4',
#     'comment_num': '168',
#     'children': []}},
#   {'name': '南海子公园',
#    'location': {'lat': 39.779482, 'lng': 116.475558},
#    'address': '黄亦路16号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '大兴区',
#    'street_id': 'f1f5cac51d653e8137b06ce4',
#    'telephone': '(010)69271456',
#    'detail': 1,
#    'uid': 'f1f5cac51d653e8137b06ce4',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.47869080683, 'lat': 39.774373927351},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=f1f5cac51d653e8137b06ce4&output=html&source=placeapi_v2',
#     'overall_rating': '3.7',
#     'comment_num': '34',
#     'children': []}},
#   {'name': '通州大运河森林公园',
#    'location': {'lat': 39.8824, 'lng': 116.748887},
#    'address': '北京市通州区宋梁路南段',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '通州区',
#    'telephone': '(010)61569200',
#    'detail': 1,
#    'uid': 'b3f6f9b15dbf37754c6d46e2',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.74665617499, 'lat': 39.881968511162},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=b3f6f9b15dbf37754c6d46e2&output=html&source=placeapi_v2',
#     'overall_rating': '4.4',
#     'comment_num': '500',
#     'children': []}},
#   {'name': '海淀公园',
#    'location': {'lat': 39.99242, 'lng': 116.302269},
#    'address': '北京市海淀区新建宫门路2号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '海淀区',
#    'street_id': '92df8c20d3c448cf52e5c5f5',
#    'telephone': '(010)62850569',
#    'detail': 1,
#    'uid': '92df8c20d3c448cf52e5c5f5',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.30585759746, 'lat': 39.994127358518},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=92df8c20d3c448cf52e5c5f5&output=html&source=placeapi_v2',
#     'overall_rating': '4.0',
#     'comment_num': '377',
#     'children': []}},
#   {'name': '月坛公园',
#    'location': {'lat': 39.922132, 'lng': 116.358874},
#    'address': '北京市西城区月坛北街6号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '西城区',
#    'street_id': '06881d62cb48756c7069d3f4',
#    'telephone': '(010)68020940',
#    'detail': 1,
#    'uid': '06881d62cb48756c7069d3f4',
#    'detail_info': {'tag': '旅游景点;文物古迹',
#     'navi_location': {'lng': 116.35891118402, 'lat': 39.923993975523},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=06881d62cb48756c7069d3f4&output=html&source=placeapi_v2',
#     'overall_rating': '4.0',
#     'comment_num': '406',
#     'children': []}},
#   {'name': '龙潭公园',
#    'location': {'lat': 39.884561, 'lng': 116.447239},
#    'address': '北京市东城区龙潭路8号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '东城区',
#    'street_id': '090059e354c3dd9114b54b97',
#    'telephone': '(010)67144336',
#    'detail': 1,
#    'uid': '090059e354c3dd9114b54b97',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.44709723227, 'lat': 39.887279611974},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=090059e354c3dd9114b54b97&output=html&source=placeapi_v2',
#     'overall_rating': '4.3',
#     'comment_num': '500',
#     'children': []}},
#   {'name': '日坛公园',
#    'location': {'lat': 39.921342, 'lng': 116.450437},
#    'address': '北京朝阳门外日坛北路6号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '朝阳区',
#    'street_id': '3dc9befd7c6f810fbea240fe',
#    'telephone': '(010)85616301',
#    'detail': 1,
#    'uid': '3dc9befd7c6f810fbea240fe',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.44782392999, 'lat': 39.921275984907},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=3dc9befd7c6f810fbea240fe&output=html&source=placeapi_v2',
#     'overall_rating': '4.4',
#     'comment_num': '500',
#     'children': []}},
#   {'name': '北海公园',
#    'location': {'lat': 39.934556, 'lng': 116.395167},
#    'address': '北京市西城区文津街1号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '西城区',
#    'street_id': '49d959381b59a043c61e5102',
#    'telephone': '(010)64040610',
#    'detail': 1,
#    'uid': '49d959381b59a043c61e5102',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.39622434792, 'lat': 39.928644063374},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=49d959381b59a043c61e5102&output=html&source=placeapi_v2',
#     'overall_rating': '4.3',
#     'comment_num': '408',
#     'children': []}},
#   {'name': '玉渊潭公园',
#    'location': {'lat': 39.922467, 'lng': 116.326526},
#    'address': '北京市海淀区西三环中路10号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '海淀区',
#    'street_id': '3810c87916332c8b9d09f7b2',
#    'telephone': '(010)88653800',
#    'detail': 1,
#    'uid': '3810c87916332c8b9d09f7b2',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.31710474177, 'lat': 39.923671634717},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=3810c87916332c8b9d09f7b2&output=html&source=placeapi_v2',
#     'overall_rating': '3.2',
#     'comment_num': '326',
#     'children': []}},
#   {'name': '念坛公园',
#    'location': {'lat': 39.711304, 'lng': 116.319487},
#    'address': '新源大街(近义和庄地铁站)',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '大兴区',
#    'street_id': 'de134f5dc2c5a2fb82288aca',
#    'telephone': '(010)61210476',
#    'detail': 1,
#    'uid': 'de134f5dc2c5a2fb82288aca',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.32753558598, 'lat': 39.71371448522},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=de134f5dc2c5a2fb82288aca&output=html&source=placeapi_v2',
#     'overall_rating': '4.4',
#     'comment_num': '190',
#     'children': []}},
#   {'name': '陶然亭公园',
#    'location': {'lat': 39.88066, 'lng': 116.388442},
#    'address': '北京市西城区太平街19号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '西城区',
#    'street_id': 'fa01e9378b06f14a774ff1f0',
#    'telephone': '(010)63511596',
#    'detail': 1,
#    'uid': 'fa01e9378b06f14a774ff1f0',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.39381642113, 'lat': 39.882520032911},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=fa01e9378b06f14a774ff1f0&output=html&source=placeapi_v2',
#     'overall_rating': '4.4',
#     'comment_num': '469',
#     'children': []}},
#   {'name': '奥林匹克森林公园',
#    'location': {'lat': 40.027453, 'lng': 116.398516},
#    'address': '北京市朝阳区科荟路33号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '朝阳区',
#    'street_id': '03d7e5971f3675483c9a5e9e',
#    'telephone': '(010)64529090',
#    'detail': 1,
#    'uid': '03d7e5971f3675483c9a5e9e',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.40813941651, 'lat': 40.02738743706},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=03d7e5971f3675483c9a5e9e&output=html&source=placeapi_v2',
#     'overall_rating': '4.3',
#     'comment_num': '500',
#     'children': []}},
#   {'name': '莲花池公园',
#    'location': {'lat': 39.898299, 'lng': 116.319518},
#    'address': '北京市丰台区西三环南路38号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '丰台区',
#    'street_id': 'edbd1d7e2b8a8760471a3244',
#    'telephone': '(010)63982357,(010)63972892',
#    'detail': 1,
#    'uid': 'edbd1d7e2b8a8760471a3244',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.3172262331, 'lat': 39.897917698131},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=edbd1d7e2b8a8760471a3244&output=html&source=placeapi_v2',
#     'overall_rating': '4.1',
#     'comment_num': '500',
#     'children': []}},
#   {'name': '紫竹院公园',
#    'location': {'lat': 39.948064, 'lng': 116.325818},
#    'address': '北京市海淀区中关村南大街35号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '海淀区',
#    'street_id': '49c6ce91c412a12c8d772700',
#    'telephone': '(010)68425851',
#    'detail': 1,
#    'uid': '49c6ce91c412a12c8d772700',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.32202091899, 'lat': 39.946392377119},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=49c6ce91c412a12c8d772700&output=html&source=placeapi_v2',
#     'overall_rating': '4.5',
#     'comment_num': '426',
#     'children': []}},
#   {'name': '梨园主题公园',
#    'location': {'lat': 39.880777, 'lng': 116.684007},
#    'address': '北京市通州区梨园镇(临河里地铁站南侧)',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '通州区',
#    'street_id': '175603966ba67aa9b4265515',
#    'detail': 1,
#    'uid': '175603966ba67aa9b4265515',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.68744100763, 'lat': 39.879336978819},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=175603966ba67aa9b4265515&output=html&source=placeapi_v2',
#     'overall_rating': '3.1',
#     'comment_num': '50',
#     'children': []}},
#   {'name': '北宫国家森林公园',
#    'location': {'lat': 39.871839, 'lng': 116.12471},
#    'address': '北京市丰台区长辛店镇大灰厂东路55号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '丰台区',
#    'street_id': 'f60a15ed8f5278ecbb17e704',
#    'telephone': '(010)83840830',
#    'detail': 1,
#    'uid': 'f60a15ed8f5278ecbb17e704',
#    'detail_info': {'tag': '旅游景点;风景区',
#     'navi_location': {'lng': 116.129089, 'lat': 39.865599080839},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=f60a15ed8f5278ecbb17e704&output=html&source=placeapi_v2',
#     'overall_rating': '3.7',
#     'comment_num': '114',
#     'children': []}},
#   {'name': '北京动物园',
#    'location': {'lat': 39.947735, 'lng': 116.343376},
#    'address': '北京市西城区西直门外大街137号',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '西城区',
#    'street_id': '4bb049d91598944799005000',
#    'telephone': '(010)68314411,(010)68390274',
#    'detail': 1,
#    'uid': '4bb049d91598944799005000',
#    'detail_info': {'tag': '旅游景点;动物园',
#     'navi_location': {'lng': 116.34531849036, 'lat': 39.944191992334},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=4bb049d91598944799005000&output=html&source=placeapi_v2',
#     'overall_rating': '4.1',
#     'comment_num': '356',
#     'children': []}},
#   {'name': '北京野生动物园',
#    'location': {'lat': 39.502531, 'lng': 116.342213},
#    'address': '北京市大兴区榆垡镇万亩森林内',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '大兴区',
#    'street_id': 'e85e2527b6f7615395f08cf8',
#    'telephone': '(010)89216606',
#    'detail': 1,
#    'uid': 'e85e2527b6f7615395f08cf8',
#    'detail_info': {'tag': '旅游景点;动物园',
#     'navi_location': {'lng': 116.32936938595, 'lat': 39.503047664253},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=e85e2527b6f7615395f08cf8&output=html&source=placeapi_v2',
#     'overall_rating': '4.1',
#     'comment_num': '124',
#     'children': []}},
#   {'name': '北京植物园',
#    'location': {'lat': 40.007561, 'lng': 116.216186},
#    'address': '北京市海淀区香山南路',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '海淀区',
#    'street_id': '550fd5f9c8d53478931fc9c4',
#    'telephone': '(010)82598771',
#    'detail': 1,
#    'uid': '550fd5f9c8d53478931fc9c4',
#    'detail_info': {'tag': '旅游景点;植物园',
#     'navi_location': {'lng': 116.216342, 'lat': 39.999807069994},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=550fd5f9c8d53478931fc9c4&output=html&source=placeapi_v2',
#     'overall_rating': '4.0',
#     'comment_num': '157',
#     'children': []}},
#   {'name': '北京西山国家森林公园(昌华园区)',
#    'location': {'lat': 39.978428, 'lng': 116.209339},
#    'address': '北京市海淀区闵庄路与香山南路交叉口西行100米',
#    'province': '北京市',
#    'city': '北京市',
#    'area': '海淀区',
#    'street_id': '1d4bc84384a3c926eedfca70',
#    'telephone': '(010)62720251',
#    'detail': 1,
#    'uid': '1d4bc84384a3c926eedfca70',
#    'detail_info': {'tag': '旅游景点;公园',
#     'navi_location': {'lng': 116.21123524682, 'lat': 39.978974404551},
#     'type': 'scope',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=1d4bc84384a3c926eedfca70&output=html&source=placeapi_v2',
#     'overall_rating': '4.3',
#     'comment_num': '500',
#     'children': []}}]}

# %% [markdown]
# ## 14.3.1 获取所有拥有公园的城市

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json

def getjson(loc):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': 0, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

province_list = ['江苏省', '浙江省', '广东省', '福建省', '山东省', '河南省', '河北省', '四川省', '辽宁省', '云南省', 
                 '湖南省', '湖北省', '江西省', '安徽省', '山西省', '广西壮族自治区', '陕西省', '黑龙江省', '内蒙古自治区', 
                 '贵州省', '吉林省', '甘肃省', '新疆维吾尔自治区', '海南省', '宁夏回族自治区', '青海省', '西藏自治区']
for eachprovince in province_list:
    decodejson = getjson(eachprovince)
    for eachcity in decodejson['results']:
        city = eachcity['name']
        num = eachcity['num']
        print (city, num)
        output = '\t'.join([city, str(num)]) + '\r\n'
        with open('cities.txt', "a+", encoding='utf-8') as f:
            f.write(output)
            f.close()
# Out:
# 苏州市 3067
# 南京市 2547
# 无锡市 2324
# 常州市 1432
# 南通市 1201
# 徐州市 1057
# 盐城市 850
# 宿迁市 818
# 扬州市 609
# 镇江市 568
# 泰州市 558
# 淮安市 520
# 连云港市 427
# 杭州市 2495
# 温州市 2114
# 宁波市 1764
# 嘉兴市 869
# 金华市 776
# 台州市 661
# 绍兴市 632
# 湖州市 479
# 丽水市 379
# 衢州市 192
# 舟山市 131
# 广州市 4366
# 深圳市 4850
# 东莞市 2493
# 佛山市 2652
# 惠州市 1386
# 江门市 776
# 中山市 729
# 珠海市 478
# 汕头市 452
# 梅州市 397
# 湛江市 379
# 韶关市 367
# 河源市 350
# 肇庆市 342
# 清远市 303
# 茂名市 295
# 揭阳市 226
# 阳江市 189
# 汕尾市 177
# 潮州市 155
# 云浮市 87
# 福州市 2217
# 厦门市 1364
# 泉州市 1104
# 漳州市 621
# 莆田市 353
# 宁德市 312
# 龙岩市 304
# 南平市 253
# 三明市 245
# 青岛市 1750
# 济南市 976
# 潍坊市 841
# 烟台市 735
# 威海市 680
# 淄博市 528
# 临沂市 525
# 济宁市 447
# 日照市 401
# 菏泽市 361
# 聊城市 330
# 德州市 283
# 滨州市 268
# 枣庄市 264
# 泰安市 251
# 东营市 211
# 莱芜市 116
# 郑州市 2061
# 洛阳市 784
# 开封市 506
# 新乡市 447
# 南阳市 411
# 商丘市 337
# 焦作市 312
# 平顶山市 269
# 安阳市 263
# 周口市 230
# 三门峡市 215
# 信阳市 211
# 许昌市 194
# 驻马店市 183
# 濮阳市 134
# 漯河市 121
# 鹤壁市 103
# 济源市 30
# 石家庄市 1342
# 保定市 777
# 邢台市 633
# 秦皇岛市 630
# 唐山市 606
# 邯郸市 546
# 沧州市 366
# 廊坊市 357
# 张家口市 345
# 承德市 269
# 衡水市 171
# 成都市 3436
# 绵阳市 462
# 南充市 447
# 德阳市 315
# 内江市 270
# 遂宁市 242
# 宜宾市 202
# 乐山市 190
# 泸州市 182
# 眉山市 169
# 资阳市 167
# 达州市 154
# 自贡市 142
# 广元市 140
# 攀枝花市 128
# 广安市 113
# 凉山彝族自治州 98
# 巴中市 78
# 雅安市 78
# 阿坝藏族羌族自治州 58
# 甘孜藏族自治州 55
# 沈阳市 1410
# 大连市 1625
# 抚顺市 380
# 鞍山市 274
# 营口市 211
# 盘锦市 203
# 葫芦岛市 171
# 本溪市 159
# 锦州市 156
# 丹东市 153
# 阜新市 109
# 朝阳市 96
# 铁岭市 92
# 辽阳市 89
# 昆明市 1756
# 大理白族自治州 356
# 玉溪市 285
# 西双版纳傣族自治州 275
# 曲靖市 226
# 丽江市 164
# 红河哈尼族彝族自治州 142
# 普洱市 115
# 迪庆藏族自治州 110
# 楚雄彝族自治州 109
# 昭通市 106
# 保山市 102
# 临沧市 92
# 文山壮族苗族自治州 67
# 德宏傣族景颇族自治州 51
# 怒江傈僳族自治州 14
# 长沙市 1831
# 张家界市 463
# 郴州市 445
# 株洲市 421
# 常德市 411
# 衡阳市 350
# 岳阳市 247
# 邵阳市 219
# 永州市 196
# 娄底市 181
# 湘潭市 144
# 怀化市 138
# 益阳市 133
# 湘西土家族苗族自治州 70
# 武汉市 2856
# 黄冈市 922
# 宜昌市 395
# 荆州市 293
# 十堰市 283
# 荆门市 281
# 襄阳市 262
# 黄石市 236
# 孝感市 202
# 咸宁市 184
# 随州市 134
# 恩施土家族苗族自治州 117
# 神农架林区 78
# 仙桃市 57
# 鄂州市 50
# 潜江市 46
# 天门市 41
# 南昌市 858
# 赣州市 717
# 九江市 469
# 新余市 462
# 上饶市 365
# 萍乡市 301
# 宜春市 284
# 吉安市 262
# 抚州市 239
# 景德镇市 137
# 鹰潭市 78
# 合肥市 1349
# 安庆市 431
# 宿州市 323
# 阜阳市 312
# 芜湖市 302
# 六安市 283
# 滁州市 206
# 亳州市 195
# 淮南市 180
# 宣城市 170
# 马鞍山市 164
# 蚌埠市 146
# 黄山市 138
# 巢湖市 132
# 淮北市 113
# 池州市 83
# 铜陵市 77
# 太原市 811
# 临汾市 345
# 长治市 294
# 运城市 289
# 晋中市 267
# 大同市 249
# 晋城市 189
# 吕梁市 166
# 忻州市 159
# 阳泉市 105
# 朔州市 79
# 南宁市 1102
# 桂林市 666
# 柳州市 588
# 玉林市 410
# 北海市 288
# 百色市 191
# 河池市 183
# 梧州市 150
# 贵港市 142
# 钦州市 91
# 防城港市 78
# 来宾市 72
# 贺州市 68
# 崇左市 46
# 西安市 3222
# 宝鸡市 469
# 渭南市 330
# 咸阳市 251
# 汉中市 183
# 榆林市 173
# 商洛市 156
# 安康市 125
# 延安市 95
# 铜川市 83
# 哈尔滨市 1228
# 齐齐哈尔市 178
# 牡丹江市 178
# 佳木斯市 169
# 大庆市 161
# 黑河市 137
# 伊春市 134
# 鹤岗市 97
# 绥化市 78
# 鸡西市 74
# 双鸭山市 56
# 七台河市 37
# 大兴安岭地区 17
# 呼和浩特市 518
# 包头市 435
# 鄂尔多斯市 392
# 赤峰市 203
# 呼伦贝尔市 168
# 乌海市 163
# 乌兰察布市 125
# 通辽市 122
# 巴彦淖尔市 117
# 阿拉善盟 101
# 兴安盟 101
# 锡林郭勒盟 82
# 贵阳市 1491
# 遵义市 384
# 毕节地区 202
# 黔南布依族苗族自治州 193
# 六盘水市 191
# 黔东南苗族侗族自治州 147
# 铜仁地区 141
# 黔西南布依族苗族自治州 106
# 安顺市 104
# 长春市 1404
# 延边朝鲜族自治州 431
# 吉林市 269
# 四平市 186
# 通化市 102
# 松原市 98
# 白山市 95
# 白城市 78
# 辽源市 44
# 兰州市 484
# 白银市 252
# 金昌市 181
# 平凉市 167
# 酒泉市 160
# 张掖市 128
# 武威市 128
# 定西市 111
# 天水市 98
# 临夏回族自治州 61
# 陇南市 56
# 庆阳市 48
# 甘南藏族自治州 42
# 嘉峪关市 22
# 乌鲁木齐市 520
# 昌吉回族自治州 165
# 伊犁哈萨克自治州 160
# 喀什地区 91
# 克拉玛依市 79
# 阿勒泰地区 75
# 塔城地区 64
# 阿克苏地区 58
# 巴音郭楞蒙古自治州 50
# 哈密地区 38
# 吐鲁番地区 25
# 石河子市 23
# 和田地区 22
# 博尔塔拉蒙古自治州 20
# 克孜勒苏柯尔克孜自治州 9
# 图木舒克市 6
# 五家渠市 5
# 阿拉尔市 3
# 海口市 430
# 三亚市 257
# 文昌市 49
# 儋州市 36
# 临高县 33
# 定安县 25
# 澄迈县 24
# 昌江黎族自治县 20
# 万宁市 19
# 东方市 14
# 琼海市 14
# 保亭黎族苗族自治县 12
# 陵水黎族自治县 12
# 乐东黎族自治县 11
# 琼中黎族苗族自治县 9
# 屯昌县 8
# 五指山市 5
# 白沙黎族自治县 3
# 银川市 673
# 固原市 75
# 石嘴山市 71
# 吴忠市 64
# 中卫市 34
# 西宁市 274
# 海西蒙古族藏族自治州 60
# 海南藏族自治州 35
# 海东地区 34
# 海北藏族自治州 16
# 黄南藏族自治州 10
# 玉树藏族自治州 7
# 果洛藏族自治州 5
# 拉萨市 56
# 阿里地区 19
# 林芝地区 15
# 日喀则地区 14
# 山南地区 5
# 昌都地区 4
# 那曲地区 2

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json
def getjson(loc):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': 0, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

decodejson = getjson('全国')
six_cities_list = ['北京市','上海市','重庆市','天津市','香港特别行政区','澳门特别行政区',]
for eachprovince in decodejson['results']:
    city = eachprovince['name']
    num = eachprovince['num']
    if city in six_cities_list:
        output = '\t'.join([city, str(num)]) + '\r\n'
        with open('cities.txt', "a+", encoding='utf-8') as f:
            f.write(output)
            f.close()

# %% [markdown]
# ## 14.3.2 获取所有城市的公园数据

# %%
#coding=utf-8
import pymysql

db = pymysql.connect("localhost","root","password","baidumap")
cursor = db.cursor()

sql = """CREATE TABLE city (
         id INT NOT NULL AUTO_INCREMENT,
         city VARCHAR(200) NOT NULL,
         park VARCHAR(200) NOT NULL,
         location_lat FLOAT,
         location_lng FLOAT,
         address VARCHAR(200),
         street_id VARCHAR(200),
         uid VARCHAR(200),
         created_time TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
         PRIMARY KEY (id)
         );"""
cursor.execute(sql)
db.commit()
db.close()

# %%
city_list = list()
with open("cities.txt", 'r', encoding='utf-8') as txt_file:   
    for eachLine in txt_file:
        if eachLine != "" and eachLine != "\n":
            fields = eachLine.split("\t")
            city = fields[0]
            city_list.append(city)
    txt_file.close()

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json
import pymysql
import time

db = pymysql.connect("localhost","root","password","baidumap")
cursor = db.cursor()

def getjson(loc,page_num):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': page_num, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    time.sleep(1)
    return decodejson

for eachcity in city_list:
    not_last_page = True
    page_num = 0
    while not_last_page:
        decodejson = getjson(eachcity, page_num)
        print (eachcity, page_num)
        if decodejson['results']: 
            for eachone in decodejson['results']:
                try:
                    park = eachone['name']
                except:
                    park = None
                try:
                    location_lat = eachone['location']['lat']
                except:
                    location_lat = None
                try:
                    location_lng = eachone['location']['lng']
                except:
                    location_lng = None            
                try:
                    address = eachone['address']
                except:
                    address = None              
                try:
                    street_id = eachone['street_id']
                except:
                    street_id = None            
                try:
                    uid = eachone['uid']
                except:
                    uid = None
                sql = """INSERT INTO baidumap.city
                (city, park, location_lat, location_lng, address, street_id, uid)
                VALUES
                (%s, %s, %s, %s, %s, %s, %s);"""
    
                cursor.execute(sql, (eachcity, park, location_lat, location_lng, address, street_id, uid,))
                db.commit()
            page_num += 1
        else:        
            not_last_page = False  
cursor.close()
db.close()
# Out:
# 苏州市 0
# 苏州市 1
# 苏州市 2
# 苏州市 3
# 苏州市 4
# 苏州市 5
# 苏州市 6
# 苏州市 7
# 苏州市 8
# 苏州市 9
# 苏州市 10
# 苏州市 11
# 苏州市 12
# 苏州市 13
# 苏州市 14
# 苏州市 15
# 苏州市 16
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-a8ee60ff83f2> in <module>()
#      32         decodejson = getjson(eachcity, page_num)
#      33         print (eachcity, page_num)
# ---> 34         if decodejson['results']:
#      35             for eachone in decodejson['results']:
#      36                 try:
#
# KeyError: 'results'

# %% [markdown]
# ## 14.3.3 获取所有公园的详细信息

# %%
#coding=utf-8
import pymysql

db = pymysql.connect("localhost","root","password","baidumap")
cursor = db.cursor()
sql = """CREATE TABLE park (
         id INT NOT NULL AUTO_INCREMENT,
         park VARCHAR(200) NOT NULL,
         location_lat FLOAT,
         location_lng FLOAT,
         address VARCHAR(200),
         street_id VARCHAR(200),
         telephone VARCHAR(200),
         detail INT,
         uid VARCHAR(200),
         tag VARCHAR(200),
         type VARCHAR(200),
         detail_url VARCHAR(800),
         price INT,
         overall_rating FLOAT,
         image_num INT,
         comment_num INT,
         shop_hours VARCHAR(800),
         alias VARCHAR(800),
         keyword VARCHAR(800),
         scope_type VARCHAR(200),
         scope_grade VARCHAR(200),
         description VARCHAR(9000),
         created_time TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
         PRIMARY KEY (id)
         );"""
cursor.execute(sql)
db.commit()
db.close()

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json
import pymysql

db = pymysql.connect("localhost","root","password","baidumap")
cursor = db.cursor()
sql = "Select uid from baidumap.city where id > 0;"

cursor.execute(sql)
db.commit()
results = cursor.fetchall()
db.close()

# %%
import requests
import json
import pymysql
import time

db = pymysql.connect("localhost","root","password","baidumap")
cursor = db.cursor()
sql = "Select uid from baidumap.city where id > 0;"

cursor.execute(sql)
db.commit()
results = cursor.fetchall()

def getjson(uid):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'uid': uid, 
        'scope': '2',
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/detail", params=pa, headers= headers)
    time.sleep(1)
    decodejson = json.loads(r.text)
    return decodejson

for row in results:
    uid = row[0]
    decodejson = getjson(uid)
    print (uid)
    info = decodejson['result']
    try:
        park = info['name']
    except:
        park = None
    try:
        location_lat = info['location']['lat']
    except:
        location_lat = None
    try:
        location_lng = info['location']['lng']
    except:
        location_lng = None            
    try:
        address = info['address']
    except:
        address = None              
    try:
        street_id = info['street_id']
    except:
        street_id = None
    try:
        telephone = info['telephone']
    except:
        telephone = None
    try:
        detail = info['detail']
    except:
        detail = None 
    try:
        tag = info['detail_info']['tag']
    except:
        tag = None            
    try:
        detail_url = info['detail_info']['detail_url']
    except:
        detail_url = None
    try:
        type = info['detail_info']['type']
    except:
        type = None            
    try:
        overall_rating = info['detail_info']['overall_rating']
    except:
        overall_rating = None
    try:
        image_num = info['detail_info']['image_num']
    except:
        image_num = None
    try:
        comment_num = info['detail_info']['comment_num']
    except:
        comment_num = None
    try:
        key_words = ''
        key_words_list = info['detail_info']['di_review_keyword']
        for eachone in key_words_list:
            key_words = key_words + eachone['keyword'] + '/'
    except:
        key_words = None
    try:
        shop_hours = info['detail_info']['shop_hours']
    except:
        shop_hours = None            
    try:
        alias = info['detail_info']['alias']
    except:
        alias = None
    try:
        scope_type = info['detail_info']['scope_type']
    except:
        scope_type = None            
    try:
        scope_grade = info['detail_info']['scope_grade']
    except:
        scope_grade = None
    try:
        description = info['detail_info']['description']
    except:
        description = None
    sql = """INSERT INTO baidumap.park
    (park, location_lat, location_lng, address, street_id, uid, telephone, detail, tag, detail_url, type, overall_rating, image_num, 
    comment_num, keyword, shop_hours, alias, scope_type, scope_grade, description)
    VALUES
    (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""

    cursor.execute(sql, (park, location_lat, location_lng, address, street_id, uid, telephone, detail, tag, detail_url, 
                      type, overall_rating, image_num, comment_num, key_words, shop_hours, alias, scope_type, scope_grade, description,))
    db.commit()
cursor.close()
db.close()
# Out:
# 764672e507ca6fb495ec849f
# 56f2f696559dd9800aa8d441
# 32e3ea700d452dac4d554706
# 9e99a96fdd6865de081cc7a6
# 083a55faa1349d60256e98b9
# 5b25f4468c4cb2ea1029354c
# f0e0156bea280b773a04b1aa
# 9d3e819abd3ab36a1d1d11ec
# c5ddcc087a310fb8d813180e
# 4201e6c702802a026d47603f
# 0104e62ad2d314fc51e5c526
# d305db1fd784d03e932ca350
# 2cc3c8e85dfe8ed64d2fdfd7
# c7474618595979fbcb213de3
# 3b7e2c39a87633309de32192
# beabdbf449b169987069d341
# e30828481d50f1c1b34c4914
# e56bf5e32cfb51440782c24f
# fa7da3e8b849db6242d63e4f
# d4034eb3ce56638bc036447a
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-8b96b41a12a0> in <module>()
#      29     decodejson = getjson(uid)
#      30     print (uid)
# ---> 31     info = decodejson['result']
#      32     try:
#      33         park = info['name']
#
# KeyError: 'result'
