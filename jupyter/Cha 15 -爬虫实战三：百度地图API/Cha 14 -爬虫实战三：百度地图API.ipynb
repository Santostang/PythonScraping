# %% [markdown]
# # 14.3 项目实施

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json

def getjson(loc):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': 0, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

getjson('北京市')
# Out:
# {'message': 'ok',
#  'results': [{'address': '北京市海淀区新建宫门路19号',
#    'detail': 1,
#    'detail_info': {'comment_num': '2239',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=2a7a25ecf9cf13636d3e1bad&output=html&source=placeapi_v2',
#     'image_num': '219',
#     'overall_rating': '3.8',
#     'price': '30',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.998475, 'lng': 116.27487},
#    'name': '颐和园',
#    'street_id': '2a7a25ecf9cf13636d3e1bad',
#    'telephone': '010-62881144',
#    'uid': '2a7a25ecf9cf13636d3e1bad'},
#   {'address': '北京市朝阳区北辰东路15号',
#    'detail': 1,
#    'detail_info': {'comment_num': '10',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=451614f6ebe67020843304a2&output=html&source=placeapi_v2',
#     'image_num': '158',
#     'overall_rating': '4',
#     'price': '30',
#     'tag': '旅游景点;公园',
#     'type': 'scope'},
#    'location': {'lat': 39.999658, 'lng': 116.402199},
#    'name': '北京奥林匹克公园',
#    'street_id': '451614f6ebe67020843304a2',
#    'telephone': '(010)84992008',
#    'uid': '451614f6ebe67020843304a2'},
#   {'address': '北京市海淀区西三环中路10号',
#    'detail': 1,
#    'detail_info': {'comment_num': '263',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=3810c87916332c8b9d09f7b2&output=html&source=placeapi_v2',
#     'image_num': '112',
#     'overall_rating': '3.3',
#     'price': '60',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.922649, 'lng': 116.326379},
#    'name': '玉渊潭公园',
#    'street_id': '3810c87916332c8b9d09f7b2',
#    'telephone': '(010)88653800',
#    'uid': '3810c87916332c8b9d09f7b2'},
#   {'address': '北京市西城区文津街1号(故宫北)',
#    'detail': 1,
#    'detail_info': {'comment_num': '848',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=49d959381b59a043c61e5102&output=html&source=placeapi_v2',
#     'image_num': '500',
#     'overall_rating': '3.2',
#     'price': '5',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.932909, 'lng': 116.39548},
#    'name': '北海公园',
#    'street_id': '49d959381b59a043c61e5102',
#    'telephone': '(010)64040610',
#    'uid': '49d959381b59a043c61e5102'},
#   {'address': '北京市朝阳区朝阳公园南路1号',
#    'detail': 1,
#    'detail_info': {'comment_num': '109',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=8c3adf1c6f135ad74d554726&output=html&source=placeapi_v2',
#     'image_num': '108',
#     'overall_rating': '4.4',
#     'price': '50',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.950229, 'lng': 116.488036},
#    'name': '朝阳公园',
#    'street_id': '8c3adf1c6f135ad74d554726',
#    'uid': '8c3adf1c6f135ad74d554726'},
#   {'address': '北京市西城区羊房胡同',
#    'detail': 1,
#    'detail_info': {'comment_num': '442',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=c21db9e5111538fe00ff2d32&output=html&source=placeapi_v2',
#     'image_num': '140',
#     'overall_rating': '4.8',
#     'price': '64',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.948094, 'lng': 116.391673},
#    'name': '什刹海公园',
#    'street_id': 'c21db9e5111538fe00ff2d32',
#    'uid': 'c21db9e5111538fe00ff2d32'},
#   {'address': '北京市西城区太平街19号(护城河北岸)',
#    'detail': 1,
#    'detail_info': {'comment_num': '489',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=fa01e9378b06f14a774ff1f0&output=html&source=placeapi_v2',
#     'groupon_num': '1',
#     'image_num': '318',
#     'overall_rating': '5',
#     'price': '20',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.880237, 'lng': 116.388222},
#    'name': '陶然亭公园',
#    'street_id': 'fa01e9378b06f14a774ff1f0',
#    'telephone': '010-63588801,63532385',
#    'uid': 'fa01e9378b06f14a774ff1f0'},
#   {'address': '北京市海淀区香山卧佛寺路',
#    'detail': 1,
#    'detail_info': {'comment_num': '372',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=550fd5f9c8d53478931fc9c4&output=html&source=placeapi_v2',
#     'image_num': '500',
#     'overall_rating': '5',
#     'tag': '旅游景点;植物园',
#     'type': 'scope'},
#    'location': {'lat': 40.008633, 'lng': 116.216315},
#    'name': '北京植物园',
#    'street_id': '550fd5f9c8d53478931fc9c4',
#    'telephone': '(010)82598771',
#    'uid': '550fd5f9c8d53478931fc9c4'},
#   {'address': '北京市石景山区八大处路3号',
#    'detail': 1,
#    'detail_info': {'comment_num': '251',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=4edf9fbf7699998dcc06a44d&output=html&source=placeapi_v2',
#     'image_num': '351',
#     'overall_rating': '4.4',
#     'price': '10',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.960973, 'lng': 116.192635},
#    'name': '八大处公园',
#    'street_id': '4edf9fbf7699998dcc06a44d',
#    'uid': '4edf9fbf7699998dcc06a44d'},
#   {'address': '北京市海淀区中关村南大街35号',
#    'detail': 1,
#    'detail_info': {'comment_num': '150',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=49c6ce91c412a12c8d772700&output=html&source=placeapi_v2',
#     'image_num': '221',
#     'overall_rating': '4.7',
#     'price': '50',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.948412, 'lng': 116.32471},
#    'name': '紫竹院公园',
#    'street_id': '49c6ce91c412a12c8d772700',
#    'telephone': '010-68425851,88412800',
#    'uid': '49c6ce91c412a12c8d772700'},
#   {'address': '北京市海淀区清华西路28号圆明园遗址公园内',
#    'detail': 1,
#    'detail_info': {'comment_num': '1311',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=62d852adf09e449a2fb17ef5&output=html&source=placeapi_v2',
#     'image_num': '265',
#     'overall_rating': '3.6',
#     'price': '15',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 40.018229, 'lng': 116.30498},
#    'name': '圆明园遗址公园',
#    'street_id': '62d852adf09e449a2fb17ef5',
#    'telephone': '010-62543673,010-62628501,010-62637561',
#    'uid': '62d852adf09e449a2fb17ef5'},
#   {'address': '丰台区长辛店镇大灰厂东路55号',
#    'detail': 1,
#    'detail_info': {'comment_num': '75',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=f60a15ed8f5278ecbb17e704&output=html&source=placeapi_v2',
#     'image_num': '127',
#     'overall_rating': '3.9',
#     'price': '10',
#     'tag': '旅游景点;公园',
#     'type': 'scope'},
#    'location': {'lat': 39.869091, 'lng': 116.127118},
#    'name': '北宫国家森林公园',
#    'street_id': 'f60a15ed8f5278ecbb17e704',
#    'telephone': '(010)83840830',
#    'uid': 'f60a15ed8f5278ecbb17e704'},
#   {'address': '东城区中华路4号(天安门西侧)',
#    'detail': 1,
#    'detail_info': {'comment_num': '178',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=e2c734e489d8d15d15a190d1&output=html&source=placeapi_v2',
#     'image_num': '117',
#     'overall_rating': '4.4',
#     'price': '20',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.916702, 'lng': 116.400582},
#    'name': '中山公园',
#    'street_id': 'e2c734e489d8d15d15a190d1',
#    'telephone': '(010)66055431',
#    'uid': 'e2c734e489d8d15d15a190d1'},
#   {'address': '北京市崇文区崇文门东大街9号',
#    'detail': 1,
#    'detail_info': {'comment_num': '68',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=6ee01020b9c09aef52e5c5d1&output=html&source=placeapi_v2',
#     'image_num': '38',
#     'overall_rating': '4.2',
#     'price': '10',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.907267, 'lng': 116.433796},
#    'name': '明城墙遗址公园',
#    'street_id': '6ee01020b9c09aef52e5c5d1',
#    'telephone': '(010)65270574',
#    'uid': '6ee01020b9c09aef52e5c5d1'},
#   {'address': '王佐镇南宫温泉度假酒店西侧',
#    'detail': 1,
#    'detail_info': {'comment_num': '43',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=9271a6024fc2257ed518b735&output=html&source=placeapi_v2',
#     'image_num': '26',
#     'overall_rating': '4.2',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.804322, 'lng': 116.149983},
#    'name': '南宫体育公园',
#    'street_id': '9271a6024fc2257ed518b735',
#    'uid': '9271a6024fc2257ed518b735'},
#   {'address': '京广线',
#    'detail': 1,
#    'detail_info': {'comment_num': '155',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=e85e2527b6f7615395f08cf8&output=html&source=placeapi_v2',
#     'groupon_num': '7',
#     'image_num': '500',
#     'overall_rating': '3.8',
#     'price': '80',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 39.502581, 'lng': 116.334877},
#    'name': '北京野生动物园',
#    'street_id': 'e85e2527b6f7615395f08cf8',
#    'telephone': '(010)89216666',
#    'uid': 'e85e2527b6f7615395f08cf8'},
#   {'address': '北京市西城区西直门外大街137号',
#    'detail': 1,
#    'detail_info': {'comment_num': '708',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=4bb049d91598944799005000&output=html&source=placeapi_v2',
#     'image_num': '500',
#     'overall_rating': '3.2',
#     'price': '10',
#     'tag': '旅游景点;动物园',
#     'type': 'scope'},
#    'location': {'lat': 39.947983, 'lng': 116.34331},
#    'name': '北京动物园',
#    'street_id': '4bb049d91598944799005000',
#    'telephone': '010-68390274',
#    'uid': '4bb049d91598944799005000'},
#   {'address': '北京市西城区松树街1号',
#    'detail': 1,
#    'detail_info': {'comment_num': '1894',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=7aea43b721dd95e17d29bda4&output=html&source=placeapi_v2',
#     'image_num': '233',
#     'overall_rating': '4.7',
#     'price': '40',
#     'tag': '旅游景点;公园',
#     'type': 'scope'},
#    'location': {'lat': 39.948226, 'lng': 116.38888},
#    'name': '后海公园',
#    'street_id': '7aea43b721dd95e17d29bda4',
#    'uid': '7aea43b721dd95e17d29bda4'},
#   {'address': '北京市朝阳区科荟路33号',
#    'detail': 1,
#    'detail_info': {'comment_num': '364',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=03d7e5971f3675483c9a5e9e&output=html&source=placeapi_v2',
#     'image_num': '168',
#     'overall_rating': '4.6',
#     'price': '6',
#     'tag': '旅游景点;风景区',
#     'type': 'scope'},
#    'location': {'lat': 40.02523, 'lng': 116.396797},
#    'name': '奥林匹克森林公园',
#    'street_id': '03d7e5971f3675483c9a5e9e',
#    'telephone': '010-64529009',
#    'uid': '03d7e5971f3675483c9a5e9e'},
#   {'address': '东城区龙潭路8号(近华普超市)',
#    'detail': 1,
#    'detail_info': {'comment_num': '105',
#     'detail_url': 'http://api.map.baidu.com/place/detail?uid=090059e354c3dd9114b54b97&output=html&source=placeapi_v2',
#     'image_num': '120',
#     'overall_rating': '4.5',
#     'price': '30',
#     'tag': '旅游景点;公园',
#     'type': 'scope'},
#    'location': {'lat': 39.884502, 'lng': 116.447234},
#    'name': '龙潭公园',
#    'street_id': '090059e354c3dd9114b54b97',
#    'telephone': '010-67144336',
#    'uid': '090059e354c3dd9114b54b97'}],
#  'status': 0,
#  'total': 400}

# %% [markdown]
# ## 14.3.1 获取所有拥有公园的城市

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json
def getjson(loc):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': 0, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

province_list = ['江苏省', '浙江省', '广东省', '福建省', '山东省', '河南省', '河北省', '四川省', '辽宁省', '云南省', 
                 '湖南省', '湖北省', '江西省', '安徽省', '山西省', '广西壮族自治区', '陕西省', '黑龙江省', '内蒙古自治区', 
                 '贵州省', '吉林省', '甘肃省', '新疆维吾尔自治区', '海南省', '宁夏回族自治区', '青海省', '西藏自治区']
for eachprovince in province_list:
    decodejson = getjson(eachprovince)
    for eachcity in decodejson['results']:
        city = eachcity['name']
        num = eachcity['num']        
        output = '\t'.join([city, str(num)]) + '\r\n'
        with open('cities.txt', "a+", encoding='utf-8') as f:
            f.write(output)
            f.close()

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json
def getjson(loc):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': 0, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

decodejson = getjson('全国')
six_cities_list = ['北京市','上海市','重庆市','天津市','香港特别行政区','澳门特别行政区',]
for eachprovince in decodejson['results']:
    city = eachprovince['name']
    num = eachprovince['num']
    if city in six_cities_list:
        output = '\t'.join([city, str(num)]) + '\r\n'
        with open('cities.txt', "a+", encoding='utf-8') as f:
            f.write(output)
            f.close()

# %% [markdown]
# ## 14.3.2 获取所有城市的公园数据

# %%
#coding=utf-8
import MySQLdb

conn= MySQLdb.connect(host='localhost' , user='root', passwd='root', db ='baidumap', charset="utf8")
cur = conn.cursor()
sql = """CREATE TABLE city (
         id INT NOT NULL AUTO_INCREMENT,
         city VARCHAR(200) NOT NULL,
         park VARCHAR(200) NOT NULL,
         location_lat FLOAT,
         location_lng FLOAT,
         address VARCHAR(200),
         street_id VARCHAR(200),
         uid VARCHAR(200),
         created_time TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
         PRIMARY KEY (id)
         );"""
cur.execute(sql)
cur.close()
conn.commit()
conn.close()

# %%
city_list = list()
with open("cities.txt", 'r', encoding='utf-8') as txt_file:   
    for eachLine in txt_file:
        if eachLine != "" and eachLine != "\n":
            fields = eachLine.split("\t")
            city = fields[0]
            city_list.append(city)
    txt_file.close()

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json
import MySQLdb

conn= MySQLdb.connect(host='localhost' , user='root', passwd='root', db ='baidumap', charset="utf8")
cur = conn.cursor()

def getjson(loc,page_num):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'q': '公园', 
        'region': loc,
        'scope': '2',
        'page_size': 20,
        'page_num': page_num, 
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

for eachcity in city_list:
    not_last_page = True
    page_num = 0
    while not_last_page:
        decodejson = getjson(eachcity, page_num)
        print (eachcity, page_num)
        if decodejson['results']: 
            for eachone in decodejson['results']:
                try:
                    park = eachone['name']
                except:
                    park = None
                try:
                    location_lat = eachone['location']['lat']
                except:
                    location_lat = None
                try:
                    location_lng = eachone['location']['lng']
                except:
                    location_lng = None            
                try:
                    address = eachone['address']
                except:
                    address = None              
                try:
                    street_id = eachone['street_id']
                except:
                    street_id = None            
                try:
                    uid = eachone['uid']
                except:
                    uid = None
                sql = """INSERT INTO baidumap.city
                (city, park, location_lat, location_lng, address, street_id, uid)
                VALUES
                (%s, %s, %s, %s, %s, %s, %s);"""
    
                cur.execute(sql, (eachcity, park, location_lat, location_lng, address, street_id, uid,))
                conn.commit()
            page_num += 1
        else:        
            not_last_page = False  
cur.close()
conn.close()
# Out:
# 南京市 0
# 南京市 1
# 南京市 2
# 南京市 3
# 南京市 4
# 南京市 5
# 南京市 6
# 南京市 7
# 南京市 8
# 南京市 9
# 南京市 10
# 南京市 11
# 南京市 12
# 南京市 13
# 南京市 14
# 南京市 15
# 南京市 16
# 苏州市 0
# 苏州市 1
# 苏州市 2
# 苏州市 3
# 苏州市 4
# 苏州市 5
# 苏州市 6
# 苏州市 7
# 苏州市 8
# 苏州市 9
# 苏州市 10
# 苏州市 11
# 苏州市 12
# 苏州市 13
# 苏州市 14
# 苏州市 15
# 苏州市 16
# 苏州市 17
# 苏州市 18
# 无锡市 0
# 无锡市 1
# 无锡市 2
# 无锡市 3
# 无锡市 4
# 无锡市 5
# 无锡市 6
# 无锡市 7
# 无锡市 8
# 无锡市 9
# 无锡市 10
# 无锡市 11
# 无锡市 12
# 常州市 0
# 常州市 1
# 常州市 2
# 常州市 3
# 常州市 4
# 常州市 5
# 常州市 6
# 常州市 7
# 常州市 8
# 南通市 0
# 南通市 1
# 南通市 2
# 南通市 3
# 南通市 4
# 南通市 5
# 盐城市 0
# 盐城市 1
# 盐城市 2
# 盐城市 3
# 盐城市 4
# 盐城市 5
# 盐城市 6
# 盐城市 7
# 徐州市 0
# 徐州市 1
# 徐州市 2
# 徐州市 3
# 徐州市 4
# 徐州市 5
# 徐州市 6
# 徐州市 7
# 扬州市 0
# 扬州市 1
# 扬州市 2
# 扬州市 3
# 扬州市 4
# 扬州市 5
# 扬州市 6
# 淮安市 0
# 淮安市 1
# 淮安市 2
# 淮安市 3
# 淮安市 4
# 淮安市 5
# 泰州市 0
# 泰州市 1
# 泰州市 2
# 泰州市 3
# 泰州市 4
# 泰州市 5
# 宿迁市 0
# 宿迁市 1
# 宿迁市 2
# 宿迁市 3
# 镇江市 0
# 镇江市 1
# 镇江市 2
# 镇江市 3
# 镇江市 4
# 连云港市 0
# 连云港市 1
# 连云港市 2
# 连云港市 3
# 杭州市 0
# 杭州市 1
# 杭州市 2
# 杭州市 3
# 杭州市 4
# 杭州市 5
# 杭州市 6
# 杭州市 7
# 杭州市 8
# 杭州市 9
# 杭州市 10
# 杭州市 11
# 杭州市 12
# 杭州市 13
# 杭州市 14
# 杭州市 15
# 杭州市 16
# 杭州市 17
# 杭州市 18
# 杭州市 19
# 杭州市 20
# 宁波市 0
# 宁波市 1
# 宁波市 2
# 宁波市 3
# 宁波市 4
# 宁波市 5
# 宁波市 6
# 宁波市 7
# 宁波市 8
# 宁波市 9
# 宁波市 10
# 宁波市 11
# 宁波市 12
# 宁波市 13
# 宁波市 14
# 宁波市 15
# 宁波市 16
# 温州市 0
# 温州市 1
# 温州市 2
# 温州市 3
# 温州市 4
# 温州市 5
# 温州市 6
# 温州市 7
# 温州市 8
# 温州市 9
# 温州市 10
# 温州市 11
# 温州市 12
# 温州市 13
# 嘉兴市 0
# 嘉兴市 1
# 嘉兴市 2
# 嘉兴市 3
# 嘉兴市 4
# 嘉兴市 5
# 嘉兴市 6
# 嘉兴市 7
# 嘉兴市 8
# 金华市 0
# 金华市 1
# 金华市 2
# 金华市 3
# 金华市 4
# 金华市 5
# 金华市 6
# 金华市 7
# 金华市 8
# 金华市 9
# 绍兴市 0
# 绍兴市 1
# 绍兴市 2
# 绍兴市 3
# 绍兴市 4
# 绍兴市 5
# 绍兴市 6
# 绍兴市 7
# 台州市 0
# 台州市 1
# 台州市 2
# 台州市 3
# 台州市 4
# 台州市 5
# 台州市 6
# 台州市 7
# 湖州市 0
# 湖州市 1
# 湖州市 2
# 湖州市 3
# 湖州市 4
# 丽水市 0
# 丽水市 1
# 丽水市 2
# 丽水市 3
# 衢州市 0
# 衢州市 1
# 衢州市 2
# 舟山市 0
# 舟山市 1
# 舟山市 2
# 广州市 0
# 广州市 1
# 广州市 2
# 广州市 3
# 广州市 4
# 广州市 5
# 广州市 6
# 广州市 7
# 广州市 8
# 广州市 9
# 广州市 10
# 广州市 11
# 广州市 12
# 广州市 13
# 广州市 14
# 广州市 15
# 广州市 16
# 广州市 17
# 广州市 18
# 广州市 19
# 广州市 20
# 深圳市 0
# 深圳市 1
# 深圳市 2
# 深圳市 3
# 深圳市 4
# 深圳市 5
# 深圳市 6
# 深圳市 7
# 深圳市 8
# 深圳市 9
# 深圳市 10
# 深圳市 11
# 深圳市 12
# 深圳市 13
# 深圳市 14
# 深圳市 15
# 深圳市 16
# 深圳市 17
# 深圳市 18
# 深圳市 19
# 深圳市 20
# 东莞市 0
# 东莞市 1
# 东莞市 2
# 东莞市 3
# 东莞市 4
# 东莞市 5
# 东莞市 6
# 东莞市 7
# 东莞市 8
# 东莞市 9
# 东莞市 10
# 东莞市 11
# 东莞市 12
# 东莞市 13
# 东莞市 14
# 佛山市 0
# 佛山市 1
# 佛山市 2
# 佛山市 3
# 佛山市 4
# 佛山市 5
# 佛山市 6
# 佛山市 7
# 佛山市 8
# 佛山市 9
# 佛山市 10
# 佛山市 11
# 佛山市 12
# 佛山市 13
# 佛山市 14
# 佛山市 15
# 佛山市 16
# 佛山市 17
# 佛山市 18
# 佛山市 19
# 佛山市 20
# 江门市 0
# 江门市 1
# 江门市 2
# 江门市 3
# 江门市 4
# 江门市 5
# 江门市 6
# 江门市 7
# 江门市 8
# 江门市 9
# 中山市 0
# 中山市 1
# 中山市 2
# 中山市 3
# 中山市 4
# 中山市 5
# 中山市 6
# 惠州市 0
# 惠州市 1
# 惠州市 2
# 惠州市 3
# 惠州市 4
# 惠州市 5
# 珠海市 0
# 珠海市 1
# 珠海市 2
# 珠海市 3
# 珠海市 4
# 珠海市 5
# 梅州市 0
# 梅州市 1
# 梅州市 2
# 梅州市 3
# 梅州市 4
# 湛江市 0
# 湛江市 1
# 湛江市 2
# 湛江市 3
# 湛江市 4
# 汕头市 0
# 汕头市 1
# 汕头市 2
# 汕头市 3
# 韶关市 0
# 韶关市 1
# 韶关市 2
# 韶关市 3
# 揭阳市 0
# 揭阳市 1
# 揭阳市 2
# 揭阳市 3
# 肇庆市 0
# 肇庆市 1
# 肇庆市 2
# 肇庆市 3
# 清远市 0
# 清远市 1
# 清远市 2
# 茂名市 0
# 茂名市 1
# 茂名市 2
# 阳江市 0
# 阳江市 1
# 阳江市 2
# 河源市 0
# 河源市 1
# 河源市 2
# 汕尾市 0
# 汕尾市 1
# 汕尾市 2
# 潮州市 0
# 潮州市 1
# 云浮市 0
# 云浮市 1
# 福州市 0
# 福州市 1
# 福州市 2
# 福州市 3
# 福州市 4
# 福州市 5
# 福州市 6
# 福州市 7
# 福州市 8
# 福州市 9
# 福州市 10
# 福州市 11
# 福州市 12
# 福州市 13
# 福州市 14
# 厦门市 0
# 厦门市 1
# 厦门市 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383             try:  # Python 2.7, use buffering of HTTP responses
# --> 384                 httplib_response = conn.getresponse(buffering=True)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b83491251333> in <module>()
#      28     page_num = 0
#      29     while not_last_page:
# ---> 30         decodejson = getjson(eachcity, page_num)
#      31         print (eachcity, page_num)
#      32         if decodejson['results']:
#
# <ipython-input-3-b83491251333> in getjson(loc, page_num)
#      20         'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
#      21     }
# ---> 22     r = requests.get("http://api.map.baidu.com/place/v2/search", params=pa, headers= headers)
#      23     decodejson = json.loads(r.text)
#      24     return decodejson
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#     386                 try:
# --> 387                     httplib_response = conn.getresponse()
#     388                 except Exception as e:
#     389                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## 14.3.3 获取所有公园的详细信息

# %%
#coding=utf-8
import MySQLdb

conn= MySQLdb.connect(host='localhost' , user='root', passwd='root', db ='baidumap', charset="utf8")
cur = conn.cursor()
sql = """CREATE TABLE park (
         id INT NOT NULL AUTO_INCREMENT,
         park VARCHAR(200) NOT NULL,
         location_lat FLOAT,
         location_lng FLOAT,
         address VARCHAR(200),
         street_id VARCHAR(200),
         telephone VARCHAR(200),
         detail INT,
         uid VARCHAR(200),
         tag VARCHAR(200),
         type VARCHAR(200),
         detail_url VARCHAR(800),
         price INT,
         overall_rating FLOAT,
         image_num INT,
         comment_num INT,
         shop_hours VARCHAR(800),
         alias VARCHAR(800),
         keyword VARCHAR(800),
         scope_type VARCHAR(200),
         scope_grade VARCHAR(200),
         description VARCHAR(9000),
         created_time TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
         PRIMARY KEY (id)
         );"""
cur.execute(sql)
cur.close()
conn.commit()
conn.close()

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import json
import MySQLdb

conn= MySQLdb.connect(host='localhost' , user='root', passwd='root', db ='baidumap', charset="utf8")
cur = conn.cursor()
sql = "Select uid from baidumap.city where id > 0;"

cur.execute(sql)
conn.commit()
results = cur.fetchall()
cur.close()
conn.close()

# %%
import requests
import json
import MySQLdb

conn= MySQLdb.connect(host='localhost' , user='root', passwd='root', db ='baidumap', charset="utf8")
cur = conn.cursor()
sql = "Select uid from baidumap.city where id > 0;"

cur.execute(sql)
conn.commit()
results = cur.fetchall()

def getjson(uid):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    pa = {
        'uid': uid, 
        'scope': '2',
        'output': 'json',
        'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
    }
    r = requests.get("http://api.map.baidu.com/place/v2/detail", params=pa, headers= headers)
    decodejson = json.loads(r.text)
    return decodejson

for row in results:
    uid = row[0]
    decodejson = getjson(uid)
    print (uid)
    info = decodejson['result']
    try:
        park = info['name']
    except:
        park = None
    try:
        location_lat = info['location']['lat']
    except:
        location_lat = None
    try:
        location_lng = info['location']['lng']
    except:
        location_lng = None            
    try:
        address = info['address']
    except:
        address = None              
    try:
        street_id = info['street_id']
    except:
        street_id = None
    try:
        telephone = info['telephone']
    except:
        telephone = None
    try:
        detail = info['detail']
    except:
        detail = None 
    try:
        tag = info['detail_info']['tag']
    except:
        tag = None            
    try:
        detail_url = info['detail_info']['detail_url']
    except:
        detail_url = None
    try:
        type = info['detail_info']['type']
    except:
        type = None            
    try:
        overall_rating = info['detail_info']['overall_rating']
    except:
        overall_rating = None
    try:
        image_num = info['detail_info']['image_num']
    except:
        image_num = None
    try:
        comment_num = info['detail_info']['comment_num']
    except:
        comment_num = None
    try:
        key_words = ''
        key_words_list = info['detail_info']['di_review_keyword']
        for eachone in key_words_list:
            key_words = key_words + eachone['keyword'] + '/'
    except:
        key_words = None
    try:
        shop_hours = info['detail_info']['shop_hours']
    except:
        shop_hours = None            
    try:
        alias = info['detail_info']['alias']
    except:
        alias = None
    try:
        scope_type = info['detail_info']['scope_type']
    except:
        scope_type = None            
    try:
        scope_grade = info['detail_info']['scope_grade']
    except:
        scope_grade = None
    try:
        description = info['detail_info']['description']
    except:
        description = None
    sql = """INSERT INTO baidumap.park
    (park, location_lat, location_lng, address, street_id, uid, telephone, detail, tag, detail_url, type, overall_rating, image_num, 
    comment_num, keyword, shop_hours, alias, scope_type, scope_grade, description)
    VALUES
    (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""

    cur.execute(sql, (park, location_lat, location_lng, address, street_id, uid, telephone, detail, tag, detail_url, 
                      type, overall_rating, image_num, comment_num, key_words, shop_hours, alias, scope_type, scope_grade, description,))
    conn.commit()
cur.close()
conn.close()
# Out:
# 6265d58ddc79ad61df1e5286
# f633606a1b34ba4e0b69d9fc
# 03ff6e2ecd84c091bea24001
# c8b5cdefee5cd91a130daa75
# 34e48508f7e105e2d9d891e0
# efd9d6d8cf721727ad31e57e
# e4e04e27a19a59fac6effb4d
# 5211d21956d57d417dc87633
# 22e11407a8d4a6add4b74ebd
# d52831f9e4362ba72ffaa7b7
# eef2d52832b1cfdb3be4a655
# 623390999c0c8c5f740269eb
# 04fe2d5163976352fe0eb070
# a826a1ab0fd025f32afc4877
# 2cc3c8e85bd78cd64d2fdffc
# 07f3c8b5361ca2636240a9ed
# dd6cf40292fb23273617dce0
# 2ba05251cc18ec959d82ea7b
# be1ea5efb5665abf14948e7b
# 08f1f1f5db98e0b488db7342
# 87248d960f34b8b32806ce78
# a12baa4064085e55e856fa1f
# 101bc61b20f637a3c42ba1ed
# 8d8925ffcae762b23f9a5ec6
# 3f826ed3e6c9b946d1f49eed
# 2c0bd6c594aa68d742ab9aa1
# 56f2f696a14675830aa8d41e
# 7e4e4572265b301da2d2302f
# 6136dc11f9f3ff7a7069d3a3
# 80e2676727f4f821b21e36e0
# 606ab0d0fc0d1a2a0e3ddae1
# ddf873b0aef3f78b40afe6f9
# 3da907f36e318f50b320a81e
# 0d574117ec59e459bd484261
# abef57be7f91f32a96f08cc2
# 3f24425c3bb0b33cc16c1488
# b7021bf8d32519faf5e73be0
# 6ed3083a05c1a5ca2a3a9fa1
# d5288966df674d979de3210d
# f7e43ddb2fc7b9433c9a5ed3
# d146b38881e0cfa375026982
# 5b25f4468eedb0ea102935ef
# 41392de9b700773bd6b74eb4
# 1c6f01ab088eac43734b87b8
# f05537c6a02c0d67cd04ef60
# 6c2dc4eaabc3d1826d20b9ca
# 9f97b1c5846bce05b64f541e
# 52e687ca6edc594475e5b6b6
# 0c67f67c00ebf7112efaa792
# 6bda52bf9a25ab02cc06a45a
# bdeab4c7a91540f50e3ddabe
# be1ea5efe7748ca614948e7d
# a6aedf8185d6b96ae215f939
# 04bdf4a3c099ea4f344aaeb0
# a3e8341cb9c052954bfd3f86
# b1c556e85d3e090fb4265519
# 8422e9dde8331633c17da279
# c6491f5595e0b3c7d0ff23a5
# 96b672aa995d9975ce04ef56
# eb36750395b1a11800ec0119
# 8fa14fc329c27313f7eafcc4
# f633606a1affbb4e0a69d9b1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383             try:  # Python 2.7, use buffering of HTTP responses
# --> 384                 httplib_response = conn.getresponse(buffering=True)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1ea5e819cda7> in <module>()
#      25 for row in results:
#      26     uid = row[0]
# ---> 27     decodejson = getjson(uid)
#      28     print (uid)
#      29     info = decodejson['result']
#
# <ipython-input-16-1ea5e819cda7> in getjson(uid)
#      19         'ak': 'DDtVK6HPruSSkqHRj5gTk0rc'
#      20     }
# ---> 21     r = requests.get("http://api.map.baidu.com/place/v2/detail", params=pa, headers= headers)
#      22     decodejson = json.loads(r.text)
#      23     return decodejson
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#     386                 try:
# --> 387                     httplib_response = conn.getresponse()
#     388                 except Exception as e:
#     389                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print (key_words)
# Out:
# None
