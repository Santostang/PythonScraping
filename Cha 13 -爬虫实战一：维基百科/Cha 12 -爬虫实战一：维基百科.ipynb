# %% [markdown]
# # 12.2 网站分析

# %%
#!/usr/bin/python
# coding: utf-8

import requests
from bs4 import BeautifulSoup
import time

headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
r = requests.get("https://en.wikipedia.org/wiki/Wikipedia", headers= headers)
html = r.text
bsObj = BeautifulSoup(html, "lxml")

for link in bsObj.findAll("a"):
    if 'href' in link.attrs:
        print (link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Main_Page
# /wiki/Wikipedia:About
# /wiki/Wikipedia_(disambiguation)
# /wiki/File:Wikipedia-logo-v2.svg
# /wiki/File:Wikipedia_wordmark.svg
# /wiki/Logo_of_Wikipedia
# /wiki/Glyph
# /wiki/Writing_systems
# #cite_note-1
# /wiki/File:Wikipedia_Main_Page.png
# /wiki/Main_Page
# /wiki/Internet_encyclopedia
# /wiki/Wikimedia_Foundation
# /wiki/Jimmy_Wales
# /wiki/Larry_Sanger
# #cite_note-Sidener-2
# /wiki/Slogan
# https://www.wikipedia.org
# /wiki/Alexa_Internet
# http://www.alexa.com/siteinfo/wikipedia.org
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# #cite_note-3
# /wiki/Registered_user
# /wiki/List_of_Wikipedias#Grand_total
# #cite_note-4
# /wiki/List_of_Wikipedias#Grand_total
# /wiki/Creative_Commons_licenses
# /wiki/GFDL
# /wiki/LAMP_(software_bundle)
# #cite_note-roadchap-5
# /wiki/OCLC
# //www.worldcat.org/oclc/52075003
# //upload.wikimedia.org/wikipedia/commons/0/01/GT_Wikipedia_BE.ogg
# /wiki/File:GT_Wikipedia_BE.ogg
# /wiki/Help:IPA_for_English
# //upload.wikimedia.org/wikipedia/commons/4/4c/GT_Wikipedia_AE.ogg
# /wiki/File:GT_Wikipedia_AE.ogg
# /wiki/Help:IPA_for_English
# /wiki/Help:Pronunciation_respelling_key
# /wiki/Online_encyclopedia
# #cite_note-6
# /wiki/Reference_work
# #cite_note-Tancer-7
# #cite_note-Woodson-8
# #cite_note-9
# #cite_note-Alexa_siteinfo-10
# /wiki/Wikimedia_Foundation
# #cite_note-11
# #cite_note-12
# #cite_note-13
# /wiki/Jimmy_Wales
# /wiki/Larry_Sanger
# #cite_note-KockJungSyn2016-14
# https://en.wiktionary.org/wiki/Wikipedia
# #cite_note-MiliardWho-15
# #cite_note-J_Sidener-16
# /wiki/Portmanteau
# /wiki/Wiki
# #cite_note-18
# /wiki/Special:Statistics
# #cite_note-19
# /wiki/English_Wikipedia
# #cite_note-CBS-20
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# #cite_note-small_screen-21
# /wiki/Wikipedia:Featured_Article
# /wiki/Wikipedia:Good_Article
# #cite_note-FMonday_feat_article_patterns_2-22
# #cite_note-IBM_feat_articles_hidden_pattern_2-23
# /wiki/Nature_(journal)
# /wiki/Encyclop%C3%A6dia_Britannica
# #cite_note-GilesJ2005Internet-24
# /wiki/Criticism_of_Wikipedia
# /wiki/Bias_in_Wikipedia
# #cite_note-EdwinBlack-25
# /wiki/Spin_(public_relations)
# #cite_note-Petrilli-26
# #History
# #Nupedia
# #Launch_and_early_growth
# #Milestones
# #Openness
# #Restrictions
# #Review_of_changes
# #Vandalism
# #Policies_and_laws
# #Content_policies_and_guidelines
# #Governance
# #Administrators
# #Dispute_resolution
# #Arbitration_Committee
# #Community
# #Diversity
# #Language_editions
# #Critical_reception
# #Accuracy_of_content
# #Medical_information
# #Quality_of_writing
# #Coverage_of_topics_and_systemic_bias
# #Coverage_of_topics_and_selection_bias
# #Systemic_bias
# #Identifying_the_filter-bubble_problem
# #Explicit_content
# #Privacy
# #Sexism
# #Operation
# #Wikimedia_Foundation_and_Wikimedia_movement_affiliates
# #Software_operations_and_support
# #Automated_editing
# #Wikiprojects.2C_and_assessments_of_articles.27_importance_and_quality
# #Hardware_operations_and_support
# #Internal_research_and_operational_development
# #Internal_news_publications
# #Access_to_content
# #Content_licensing
# #Methods_of_access
# #Mobile_access
# #Cultural_impact
# #Readership
# #Cultural_significance
# #Awards
# #Satire
# #Sister_projects_.E2.80.93_Wikimedia
# #Publishing
# #Scientific_use
# #Related_projects
# #See_also
# #References
# #Notes
# #Further_reading
# #Academic_studies
# #Books
# #Book_reviews_and_other_articles
# #Learning_resources
# #Other_media_coverage
# #External_links
# /wiki/History_of_Wikipedia
# /wiki/File:Jimmy_Wales_September_2015.jpg
# /wiki/File:L_Sanger.jpg
# /wiki/File:Nupedia_logo_and_wordmark.png
# /wiki/File:Nupedia_logo_and_wordmark.png
# /wiki/Nupedia
# #cite_note-27
# /wiki/Nupedia
# /wiki/English_language
# #cite_note-KockJungSyn2016-14
# /wiki/Bomis
# /wiki/Web_portal
# /wiki/Jimmy_Wales
# /wiki/Larry_Sanger
# /wiki/Editing
# /wiki/Open_Content
# /wiki/GNU_Free_Documentation_License
# /wiki/Richard_Stallman
# #cite_note-stallman1999-28
# #cite_note-autogenerated1-29
# #cite_note-Meyers-30
# #cite_note-SangerMemoir-31
# #cite_note-Sanger-32
# /wiki/Wiki
# #cite_note-WM_foundation_of_WP_1-33
# /wiki/Electronic_mailing_list
# #cite_note-nupedia_feeder_from_WP_1-34
# //upload.wikimedia.org/wikipedia/commons/f/ff/How_Wikipedia_contributes_to_free_knowledge.webm
# /wiki/File:How_Wikipedia_contributes_to_free_knowledge.webm
# http://www.cbc.ca/ideas/episodes/2014/01/15/the-great-book-of-knowledge-part-1/
# /wiki/Paul_Kennedy_(host)
# /wiki/Canadian_Broadcasting_Corporation
# #cite_note-WikipediaHome-35
# #cite_note-SangerMemoir-31
# #cite_note-NPOV-36
# #cite_note-SangerMemoir-31
# #cite_note-Seth-Finkelstein-37
# /wiki/Slashdot
# /wiki/Web_search_engine
# #cite_note-Wikipedia_August_08.2C_2001-38
# #cite_note-Wikipedia_September_25.2C_2001-39
# #cite_note-WP_early_language_stats_1-40
# /wiki/English_Wikipedia
# /wiki/Yongle_Encyclopedia
# #cite_note-EB_encyclopedia-41
# /wiki/Spanish_Wikipedia
# /wiki/Fork_(software_development)
# /wiki/Enciclopedia_Libre_Universal_en_Espa%C3%B1ol
# #cite_note-EL_fears_and_start_1-42
# #cite_note-Shirky-43
# #cite_note-guardian_WP_user_peak_1-44
# #cite_note-WP_growth_modelling_1-45
# /wiki/Palo_Alto_Research_Center
# #cite_note-wikisym_slowing_growth_1-46
# https://en.wiktionary.org/wiki/low-hanging_fruit
# #cite_note-bostonreview_the_end_of_WP_1-47
# #cite_note-48
# #cite_note-stanford_WP_lack_of_future_growth_1-49
# /wiki/Rey_Juan_Carlos_University
# /wiki/Madrid
# /wiki/Spain
# #cite_note-guardian_editors_leaving_1-50
# #cite_note-51
# #cite_note-WSJ_WP_losing_editors_1-52
# #cite_note-telegraph_Wales_WP_not_losing_editors_1-53
# #cite_note-wiki-women-54
# /wiki/Technology_Review
# #cite_note-Simonite-2013-55
# /wiki/The_Atlantic
# #cite_note-56
# /wiki/New_York_(magazine)
# #cite_note-57
# /wiki/File:History_Wikipedia_English_SOPA_2012_Blackout2.jpg
# /wiki/File:History_Wikipedia_English_SOPA_2012_Blackout2.jpg
# /wiki/Stop_Online_Piracy_Act
# //upload.wikimedia.org/wikipedia/commons/4/4d/Wikipedia_Edit_2014.webm
# /wiki/File:Wikipedia_Edit_2014.webm
# /wiki/List_of_most_popular_websites
# /wiki/ComScore
# /wiki/New_York_Times
# /wiki/Apple_Inc.
# #cite_note-58
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# #cite_note-Alexa_siteinfo-10
# #cite_note-Alexa_top-59
# /wiki/Alexa_Internet
# #cite_note-60
# /wiki/Page_view
# /wiki/Unique_visitor
# #cite_note-small_screen-21
# /wiki/Stop_Online_Piracy_Act
# /wiki/PROTECT_IP_Act
# /wiki/2012_Wikipedia_blackout
# #cite_note-LA_Times_Jan_19-61
# #cite_note-BBC_WP_blackout_protest_1-62
# #cite_note-63
# /wiki/Stigmergy
# #cite_note-sagepub_WP_and_encyclopedic_production_1-64
# #cite_note-theatlantic_WP_actually_a_reversion_1-65
# #cite_note-economictimes.indiatimes.com-66
# /wiki/Knowledge_Graph
# #cite_note-economictimes.indiatimes.com-66
# #cite_note-economictimes.indiatimes.com-66
# #cite_note-Alexa-67
# #cite_note-stats.wikimedia-68
# #cite_note-stats.wikimedia-68
# /wiki/File:History_Comparison_Example_(Vector).png
# /wiki/File:History_Comparison_Example_(Vector).png
# /wiki/Procrastination
# #cite_note-69
# #cite_note-zittrain-70
# #cite_note-zittrain-70
# #cite_note-71
# #cite_note-WP_protection_policy_1-72
# #cite_note-73
# /wiki/Help:Semi-protection
# /wiki/Wikipedia:ECP
# /wiki/Wikipedia:Autoconfirmed
# /wiki/Wikipedia:XCON
# #cite_note-74
# /wiki/Administrators_(Wikipedia)
# #cite_note-75
# /wiki/German_Wikipedia
# #cite_note-WP_some_sites_stable_versions_1-76
# #cite_note-BInsider_pending_changes_intro_1-77
# #cite_note-78
# /wiki/File:Wikipedia_editing_interface.png
# /wiki/File:Wikipedia_editing_interface.png
# #cite_note-79
# #cite_note-Torsten_Kleinz-80
# /wiki/Help:Recent_changes
# /wiki/Recent_changes
# #cite_note-81
# /wiki/Transaction_cost
# /wiki/Wiki
# #cite_note-FMonday_collaborative_effort_1-82
# /wiki/Vandalism_on_Wikipedia
# #cite_note-upenn_link_spamming_1-83
# #cite_note-WP_vandalism_manipulation_1-84
# /wiki/File:John_Seigenthaler_Sr._speaking.jpg
# /wiki/File:John_Seigenthaler_Sr._speaking.jpg
# /wiki/John_Seigenthaler
# /wiki/Seigenthaler_incident
# #cite_note-MIT_IBM_study-85
# #cite_note-CreatingDestroyingAndRestoringValue-86
# #cite_note-Seigenthaler-87
# /wiki/Seigenthaler_biography_incident
# /wiki/John_Seigenthaler
# #cite_note-Seigenthaler-87
# #cite_note-Seigenthaler-87
# /wiki/USA_Today
# /wiki/Freedom_Forum
# /wiki/First_Amendment_Center
# /wiki/Vanderbilt_University
# #cite_note-book_The_World_is_Flat_1-88
# #cite_note-89
# #cite_note-Seigenthaler-87
# /wiki/Wikipedia:Biographies_of_living_persons
# #cite_note-90
# /wiki/Wikipedia:Five_pillars
# /wiki/File:Jimbo_at_Fosdem_cropped.jpg
# http://www.cbsnews.com/news/wikipedia-jimmy-wales-morley-safer-60-minutes/
# /wiki/60_Minutes
# /wiki/CBS
# /wiki/Copyright
# /wiki/Virginia
# /wiki/Wikipedia:Five_pillars
# /wiki/Wikipedia:List_of_policies_and_guidelines
# #cite_note-pcworld_who.27s_behind_WP-91
# /wiki/Wikipedia:Enforcement
# #cite_note-WP_some_sites_stable_versions_1-76
# https://en.wiktionary.org/wiki/encyclopedic
# #cite_note-WP_content_policy_1-92
# /wiki/Notability_in_the_English_Wikipedia
# #cite_note-WP_notability_guide_1-93
# #cite_note-NOR-94
# /wiki/Wikipedia:No_original_research
# /wiki/Wikipedia:Identifying_reliable_sources
# #cite_note-WP_Verifiability_policy_1-95
# #cite_note-IHT_WP_valid_info_wrong_removable_1-96
# #cite_note-autogenerated2-97
# #cite_note-alternet_WP_unethical_editing_destroy.27s_credibility_1-98
# /wiki/Wikipedia:Administration
# /wiki/Anarchy
# /wiki/Democracy
# #cite_note-99
# #cite_note-100
# #cite_note-101
# /wiki/Tragedy_of_the_commons
# /wiki/Flow_(psychology)
# #cite_note-102
# /wiki/Administrators_(Wikipedia)
# #cite_note-103
# #cite_note-David_Mehegan-104
# #cite_note-105
# #cite_note-106
# #cite_note-107
# /wiki/Wikipedia:EW
# #cite_note-108
# #cite_note-NBC_WP_editorial_warzone_1-109
# #cite_note-110
# /wiki/Wikipedia:Third_opinion
# /wiki/Wikipedia:RfC
# /wiki/Arbitration_Committee
# #cite_note-emory_disputes_handled_1-111
# /wiki/Wikipedia:Neutral_point_of_view
# /wiki/Wikipedia:Probation
# /wiki/Wikipedia:BAN
# /wiki/Anti-social_behavior
# #cite_note-112
# /wiki/Wikipedia_community
# //upload.wikimedia.org/wikipedia/commons/6/61/Wikimania_-_the_Wikimentary.webm
# /wiki/File:Wikimania_-_the_Wikimentary.webm
# /wiki/Wikimania#2005
# /wiki/Wikimedia_Foundation
# /wiki/Frankfurt_am_Main
# /wiki/Germany
# #cite_note-113
# //upload.wikimedia.org/wikipedia/commons/2/27/Editing_Hoxne_Hoard_at_the_British_Museum.ogv
# /wiki/File:Editing_Hoxne_Hoard_at_the_British_Museum.ogv
# /wiki/British_Museum
# /wiki/Hoxne_Hoard
# /wiki/Cult
# #cite_note-114
# #cite_note-115
# /wiki/Credential
# /wiki/Anti-elitism
# #cite_note-116
# /wiki/Wikipedia:Barnstars
# #cite_note-117
# #cite_note-user_identification-118
# #cite_note-119
# #cite_note-blodget-120
# #cite_note-121
# /wiki/Aaron_Swartz
# #cite_note-122
# /wiki/Special:Statistics
# /wiki/Special:ActiveUsers
# /wiki/Special:ActiveUsers
# #cite_note-labor_squeeze_on_WP_1-123
# #cite_note-labor_squeeze_on_WP_1-123
# #cite_note-legal_edu_and_WP_1-124
# /wiki/IP_addresses
# /wiki/Dartmouth_College
# #cite_note-sciam_good_samaritans_1-125
# #cite_note-blodget-120
# /wiki/Business_Insider
# /wiki/Henry_Blodget
# #cite_note-blodget-120
# #cite_note-liebertonline_view_on_WP_users_1-126
# #cite_note-newscientist_view_on_WP_users_1-127
# #cite_note-128
# #cite_note-newscientist_WP_boom_to_bust_1-129
# /wiki/File:WMF_Strategic_Plan_Survey.svg
# /wiki/File:WMF_Strategic_Plan_Survey.svg
# #cite_note-130
# /wiki/University_of_Minnesota
# #cite_note-131
# /wiki/New_York_Times
# #cite_note-132
# /wiki/Sue_Gardner
# #cite_note-NYT_WP_contributors_gender_1-133
# #cite_note-NYT_WP_male_domination_1-134
# /wiki/Edit-a-thon
# #cite_note-135
# #cite_note-136
# /wiki/Jimmy_Wales
# /wiki/Wikimedia_Foundation
# #cite_note-BBC-137
# /wiki/Bloomberg_News
# #cite_note-138
# /wiki/List_of_Wikipedias
# /wiki/English_Wikipedia
# /wiki/Swedish_Wikipedia
# /wiki/Cebuano_Wikipedia
# /wiki/German_Wikipedia
# /wiki/Dutch_Wikipedia
# /wiki/French_Wikipedia
# /wiki/Russian_Wikipedia
# /wiki/Italian_Wikipedia
# /wiki/Spanish_Wikipedia
# /wiki/Waray-Waray_Wikipedia
# /wiki/Polish_Wikipedia
# /wiki/Vietnamese_Wikipedia
# /wiki/Japanese_Wikipedia
# /wiki/Portuguese_Wikipedia
# /wiki/Chinese_Wikipedia
# /wiki/Ukrainian_Wikipedia
# /wiki/Catalan_Wikipedia
# /wiki/Persian_Wikipedia
# #cite_note-ListOfWikipedias-139
# #cite_note-WP_list_of_WPs_1-140
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# /wiki/Subdomain
# #cite_note-Alexa_siteinfo-10
# /wiki/English_Wikipedia
# /wiki/Cebuano_Wikipedia
# /wiki/Swedish_Wikipedia
# /wiki/German_Wikipedia
# /wiki/Dutch_Wikipedia
# /wiki/French_Wikipedia
# #cite_note-WP_list_of_WPs_by_article_1-141
# #cite_note-meta.wikimedia-142
# /wiki/English_Wikipedia
# /wiki/Cebuano_Wikipedia
# /wiki/Swedish_Wikipedia
# /wiki/German_Wikipedia
# /wiki/Dutch_Wikipedia
# /wiki/French_Wikipedia
# /wiki/Russian_Wikipedia
# /wiki/Italian_Wikipedia
# /wiki/Spanish_Wikipedia
# /wiki/Waray_Wikipedia
# /wiki/Polish_Wikipedia
# /wiki/Vietnamese_Wikipedia
# /wiki/Japanese_Wikipedia
# /wiki/Portuguese_Wikipedia
# #cite_note-143
# /wiki/English_Wikipedia
# /wiki/Cebuano_Wikipedia
# /wiki/Swedish_Wikipedia
# /wiki/German_Wikipedia
# /wiki/Dutch_Wikipedia
# /wiki/French_Wikipedia
# /wiki/Russian_Wikipedia
# /wiki/Italian_Wikipedia
# /wiki/Spanish_Wikipedia
# /wiki/Waray_Wikipedia
# /wiki/Polish_Wikipedia
# /wiki/Vietnamese_Wikipedia
# /wiki/Japanese_Wikipedia
# /wiki/Portuguese_Wikipedia
# /wiki/Chinese_Wikipedia
# /wiki/Ukrainian_Wikipedia
# /wiki/Persian_Wikipedia
# /wiki/Catalan_Wikipedia
# /wiki/Arabic_Wikipedia
# /wiki/Norwegian_Wikipedia
# /wiki/World_Wide_Web
# /wiki/English_Wikipedia
# /wiki/American_and_British_English_spelling_differences
# /wiki/Color
# #cite_note-WP_spelling_MOS_1-144
# #cite_note-WP_countering_bias_1-145
# /wiki/Free_content
# /wiki/Fair_use
# #cite_note-WP_meta_fair_use_1-146
# #cite_note-WP_meta_WP_images_1-147
# #cite_note-IBM_visual_WP_1-148
# #cite_note-WP_Wales_free_multi-lingual_encyclopedia-149
# #cite_note-WP_metawiki_maintenance_1-150
# #cite_note-WP_meta_stats_1-151
# #cite_note-WP_meta_articles_on_all_sites_1-152
# /wiki/File:User_-_demography.svg
# /wiki/File:User_-_demography.svg
# #cite_note-WP_auto-translations_rules_1-153
# /wiki/Interwiki_links
# /wiki/PLOS_ONE
# /wiki/North_America
# /wiki/English_Wikipedia
# /wiki/Simple_English_Wikipedia
# #cite_note-154
# #cite_note-WP_global_south_demographic_increase_plan_1-155
# #cite_note-economist1-156
# #cite_note-economist1-156
# #cite_note-economist1-156
# #cite_note-157
# /wiki/Academic_studies_about_Wikipedia
# /wiki/Criticism_of_Wikipedia
# /wiki/Criticism_of_Wikipedia#Excessive_regulation
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# #cite_note-bureaucracy-158
# #cite_note-159
# /wiki/Systemic_bias
# /wiki/Edwin_Black
# #cite_note-EdwinBlack-25
# /wiki/The_Chronicle_of_Higher_Education
# /wiki/The_Journal_of_Academic_Librarianship
# /wiki/Wikipedia:Undue
# #cite_note-160
# #cite_note-161
# #cite_note-162
# /wiki/Oliver_Kamm
# /wiki/Edwin_Black
# #cite_note-EdwinBlack-25
# #cite_note-okw-163
# /wiki/Education_Next
# /wiki/Spin_(public_relations)
# #cite_note-Petrilli-26
# /wiki/Plagiarism
# #cite_note-wwplagiarism-164
# /wiki/Reliability_of_Wikipedia
# /wiki/Encyclop%C3%A6dia_Britannica
# #cite_note-165
# #cite_note-GilesJ2005Internet-24
# #cite_note-166
# #cite_note-corporate.britannica.com-167
# #cite_note-nature.com_britannica_response_1-168
# #cite_note-nature.com-169
# /wiki/Confidence_interval
# #cite_note-170
# #cite_note-WP_general_disclaimer_1-171
# /wiki/Accountability
# #cite_note-WikipediaWatch-172
# #cite_note-pcworld_WP_blunders_1-173
# /wiki/Vandalism_on_Wikipedia
# /wiki/Tyler_Cowen
# #cite_note-tnr_experts_vigilant_in_correcting_WP_1-174
# #cite_note-TNY_reliability_issues_1-175
# #cite_note-AcademiaAndWikipedia-176
# /wiki/Reference_work
# /wiki/Utility
# #cite_note-McHenry_2004-177
# http://www.dw.de/inside-wikipedia-attack-of-the-pr-industry/av-17745881
# /wiki/Deutsche_Welle
# #cite_note-dw-178
# /wiki/Troll_(Internet)
# /wiki/Spam_(electronic)
# #cite_note-Torsten_Kleinz-80
# #cite_note-citizendium_WP_trolling_issues_1-179
# /wiki/Conflict-of-interest_editing_on_Wikipedia
# #cite_note-ReferenceA-180
# /wiki/Katherine_Maher
# #cite_note-ReferenceA-180
# #cite_note-DeathByWikipedia-181
# #cite_note-cnet_politicians_and_WP_1-182
# #cite_note-msnbc_MS_cash_for_WP_edits_1-183
# #cite_note-Seeing_Corporate_Fingerprints-184
# /wiki/Stephen_Colbert
# /wiki/The_Colbert_Report
# #cite_note-wikiality-185
# /wiki/Lecturer
# /wiki/Academia
# /wiki/Primary_source
# #cite_note-WideWorldOfWikipedia-186
# #cite_note-insidehighered_against_WP_1-187
# #cite_note-insidehighered_wiki_no_cite-188
# #cite_note-AWorkInProgress-189
# /wiki/Email
# #cite_note-Jimmy_Wales_don.27t_cite_WP_1-190
# /wiki/The_Harvard_Crimson
# /wiki/Harvard_University
# /wiki/Syllabus
# #cite_note-thecrimson_wiki_debate-191
# /wiki/American_Library_Association
# /wiki/Michael_Gorman_(librarian)
# /wiki/Google
# #cite_note-stothart-192
# #cite_note-Nutshell_in-depth_resources-193
# /wiki/Health_information_on_Wikipedia
# #cite_note-Julie_Beck_2014-194
# /wiki/Amin_Azzam
# /wiki/Health_information_on_Wikipedia
# /wiki/James_Heilman
# #cite_note-Julie_Beck_2014-194
# #cite_note-theatlantic.com-195
# #cite_note-theatlantic.com-195
# /wiki/Carnegie_Mellon_University
# #cite_note-196
# /wiki/Roy_Rosenzweig
# #cite_note-Rosenzweig-197
# /wiki/Abraham_Lincoln
# /wiki/American_Civil_War
# /wiki/James_M._McPherson
# /wiki/William_Clarke_Quantrill
# #cite_note-Rosenzweig-197
# #cite_note-theregister_Wales_WP_founder_on_quality_1-198
# /wiki/Cancer
# /wiki/Thomas_Jefferson_University
# #cite_note-upi_accuracy_1-199
# #cite_note-economist_incomplete_info-200
# /wiki/Notability_in_the_English_Wikipedia
# /wiki/Criticism_of_Wikipedia#Systemic_bias_in_coverage
# https://www.wikidata.org/wiki/Wikidata:Statistics/Wikipedia
# /wiki/Terabyte
# #cite_note-WP_advantages_over_trad_media_1-201
# /wiki/Deletionism_and_inclusionism_in_Wikipedia
# #cite_note-Economist_disagreements_not_uncommon-202
# #cite_note-telegraph_WP_torn_apart_1-203
# /wiki/Wikipedia:Wikipedia_is_not#Wikipedia_is_not_censored
# /wiki/Online_petition_on_Wikipedia_Muhammad_article
# /wiki/English_Wikipedia
# /wiki/Muhammad
# /wiki/Censorship_of_Wikipedia
# /wiki/China
# #cite_note-Taylor-204
# /wiki/Pakistan
# #cite_note-washington_post_state_censorship_1-205
# /wiki/United_Kingdom
# #cite_note-BBC_child_image_censored_1-206
# /wiki/File:Wikipedia_content_by_subject.png
# /wiki/File:Wikipedia_content_by_subject.png
# #cite_note-Kittur2009-207
# #cite_note-Kittur2009-207
# /wiki/Wikipedia:Wikipedia_Loves_Libraries
# /wiki/New_York_Public_Library_for_the_Performing_Arts
# #cite_note-NYT_subjects_and_articles-208
# /wiki/University_of_Minnesota
# #cite_note-209
# /wiki/Oxford_Internet_Institute
# /wiki/Africa
# #cite_note-210
# /wiki/The_Guardian
# /wiki/List_of_pornographic_actresses_by_decade
# /wiki/Women_writer
# #cite_note-GuardianAugust2014-211
# /wiki/Systemic_bias
# #cite_note-wiki-women-54
# /wiki/Criticism_of_Wikipedia#Excessive_regulation
# #Decline_in_participation_since_2009
# #cite_note-Simonite-2013-55
# /wiki/Bias_in_Wikipedia
# #cite_note-Quilter-212
# /wiki/Internet_culture
# #cite_note-Quilter-212
# /wiki/University_of_Oxford
# #cite_note-213
# #cite_note-autogenerated3-214
# /wiki/Counterproductive_work_behavior
# /wiki/George_W._Bush
# /wiki/Anarchism
# /wiki/Muhammad
# #cite_note-autogenerated3-214
# /wiki/Croatia
# /wiki/Scientology
# /wiki/9/11_conspiracy_theories
# #cite_note-autogenerated3-214
# /wiki/Washington_University
# #cite_note-215
# #cite_note-216
# /wiki/Filter_bubble
# #cite_note-Kessenides-217
# /wiki/Eli_Pariser
# /wiki/Upworthy
# #cite_note-Kessenides-217
# /wiki/Internet_Watch_Foundation_and_Wikipedia
# /wiki/Reporting_of_child_pornography_images_on_Wikimedia_Commons
# #cite_note-autogenerated4-218
# /wiki/Feces
# /wiki/Cadaver
# /wiki/Human_penis
# /wiki/Vulva
# /wiki/Nudity
# /wiki/Sexual_content
# /wiki/Masturbation
# /wiki/Ejaculation
# /wiki/Child_nudity
# /wiki/Zoophilia
# /wiki/Hardcore_pornography
# /wiki/Virgin_Killer
# /wiki/Music_of_Germany
# /wiki/Heavy_metal_music
# /wiki/Rock_band
# /wiki/Scorpions_(band)
# /wiki/Prepubescent
# /wiki/Internet_service_provider
# /wiki/Internet_Watch_Foundation
# #cite_note-Register_ISP_censorship-219
# #cite_note-WP_free_speech_debate-220
# /wiki/Wikimedia_Commons
# /wiki/United_States_obscenity_law
# #cite_note-221
# #cite_note-Inquirer_child_abuse_allegations-222
# /wiki/Pedophilia
# /wiki/Lolicon
# /wiki/Child_pornography_laws_in_the_United_States#Section_1466A
# #cite_note-The_Register-April-223
# /wiki/Obscenity#United_States_obscenity_law
# #cite_note-The_Register-April-223
# #cite_note-TET_child_porn_accusations-224
# /wiki/Wikimedia_Foundation
# #cite_note-AFP-225
# #cite_note-AFP-225
# #cite_note-BBC_News_Wales_cedes_rights-226
# /wiki/Wikipediocracy
# #cite_note-XBIZ-227
# /wiki/Privacy
# /wiki/Public_figure
# #cite_note-228
# #cite_note-229
# /wiki/Cyberspace
# /wiki/Real_life
# /wiki/Meatspace
# /wiki/German_Wikipedia
# /wiki/Tron_(hacker)
# /wiki/Right_to_privacy
# #cite_note-heise_Tron_public_issue_1-230
# /wiki/OTRS
# #cite_note-231
# /wiki/Sexism
# /wiki/Harassment
# #cite_note-232
# #cite_note-233
# #cite_note-CSM-misogyny-234
# /wiki/Cunt
# #cite_note-235
# /wiki/Wikipedia:WikiProject
# #cite_note-236
# /wiki/Wikimedia_Foundation
# /wiki/File:Katherine_Maher.jpg
# /wiki/File:Katherine_Maher.jpg
# /wiki/Wikimedia_Foundation
# /wiki/Wiktionary
# /wiki/Wikibooks
# #cite_note-financialstatements-237
# #cite_note-238
# /wiki/Lila_Tretikov
# #cite_note-239
# #cite_note-Jeff_Elder_2014-240
# #cite_note-nytimes.com-241
# /wiki/Conflict-of-interest_editing_on_Wikipedia
# #cite_note-Jeff_Elder_2014-240
# #cite_note-242
# #cite_note-243
# /wiki/Wikimedia_movement_affiliates
# /wiki/List_of_Wikimedia_chapters
# /wiki/Catalan_language
# /wiki/MediaWiki
# /wiki/MediaWiki
# /wiki/Free_software
# /wiki/Open_source_software
# /wiki/Wiki_software
# /wiki/PHP
# /wiki/MySQL
# #cite_note-nedworks_database_system-244
# /wiki/Macro_(computer_science)
# /wiki/Variable_(programming)
# /wiki/Transclusion
# /wiki/Web_template
# /wiki/URL_redirection
# /wiki/GNU_General_Public_License
# /wiki/UseModWiki
# /wiki/Perl
# /wiki/CamelCase
# /wiki/PhpWiki
# /wiki/Magnus_Manske
# /wiki/Exponential_growth
# /wiki/Lee_Daniel_Crocker
# #cite_note-WP_extensions_installed-245
# /wiki/Lucene
# #cite_note-246
# #cite_note-247
# /wiki/MySQL
# #cite_note-248
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# /wiki/Java_(programming_language)
# #cite_note-249
# /wiki/VisualEditor
# #cite_note-thenextwebve-250
# #cite_note-251
# #cite_note-TheEconomistVE-252
# #cite_note-softpedia-best-253
# #cite_note-Orlowski.2C_Andrew-254
# /wiki/Internet_bot
# #cite_note-255
# #cite_note-meetbots-256
# #cite_note-257
# #cite_note-258
# #cite_note-259
# /wiki/User:ClueBot_NG
# #cite_note-meetbots-256
# #cite_note-260
# #cite_note-261
# /wiki/Andrew_Lih
# #cite_note-262
# /wiki/Transclusion
# /wiki/English_Wikipedia
# //en.wikipedia.org/w/index.php?title=English_Wikipedia&action=edit
# //en.wikipedia.org/w/index.php?title=English_Wikipedia&action=history
# /wiki/WikiProject
# /wiki/WikiProject
# /wiki/Social_group
# /wiki/Women%27s_history
# /wiki/Wikipedia:Database_reports/WikiProjects_by_changes
# #cite_note-263
# #cite_note-WP_1.0_editorial_team_1-264
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Featured_articles
# /wiki/Main_page
# #cite_note-FMonday_feat_article_patterns_1-265
# #cite_note-IBM_feat_articles_hidden_pattern_1-266
# /wiki/Wikipedia:Version_1.0_Editorial_Team
# #cite_note-Poderi_Giacomo_feat_articles_1-267
# #cite_note-FMonday_WP_quality_control_1-268
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# #cite_note-en.wikipedia-269
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# #cite_note-en.wikipedia-269
# /wiki/Category:Top-importance_articles
# /wiki/Category:High-importance_articles
# /wiki/Category:Mid-importance_articles
# /wiki/Category:Low-importance_articles
# /wiki/Category:Unassessed_articles
# /wiki/File:Featured_article_star.svg
# /wiki/Category:FA-Class_articles
# /wiki/File:Featured_article_star.svg
# /wiki/Category:FL-Class_articles
# /wiki/File:Symbol_a_class.svg
# /wiki/Category:A-Class_articles
# /wiki/Category:GA-Class_articles
# /wiki/Category:B-Class_articles
# /wiki/Category:C-Class_articles
# /wiki/Category:Start-Class_articles
# /wiki/Category:Stub-Class_articles
# /wiki/Category:List-Class_articles
# /wiki/Category:Unassessed_articles
# /wiki/Wikipedia:Version_1.0_Editorial_Team
# /wiki/User:WP_1.0_bot
# /wiki/Wikimedia_Foundation#Hardware
# #cite_note-WP_tools_requests_per_day-270
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# /wiki/Squid_(software)
# #cite_note-site_internals_configuration-271
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# #cite_note-globule_access_trace-272
# /wiki/Linux_Virtual_Server
# /wiki/File:Wikimedia-servers-2010-12-28.svg
# /wiki/File:Wikimedia-servers-2010-12-28.svg
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# /wiki/Cluster_(computing)
# /wiki/Linux
# /wiki/Ubuntu_(operating_system)
# #cite_note-CW_WP_simplifies_infrastructure-273
# #cite_note-ars_tech_Ubuntu_server_infra-274
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# /wiki/Amsterdam
# #cite_note-servers-275
# /wiki/Equinix
# /wiki/Ashburn,_Virginia
# #cite_note-276
# #cite_note-277
# #cite_note-Simonite-2013-55
# /wiki/Industrial_organization
# #cite_note-autogenerated5-278
# #cite_note-Simonite-2013-55
# #cite_note-Orlowski.2C_Andrew-254
# #cite_note-Patents.2C_Citations_pp_89-153-279
# #cite_note-Patents.2C_Citations_pp_89-153-279
# #cite_note-Patents.2C_Citations_pp_89-153-279
# /wiki/English_Wikipedia
# /wiki/Wikipedia:Signpost
# /wiki/Wikimedia_Foundation
# #cite_note-280
# /wiki/Wikimedia_project
# /wiki/Wikimedia_Commons
# https://de.wikipedia.org/wiki/WP:Kurier
# https://pt.wikipedia.org/wiki/wp:Correio_da_Wikip%C3%A9dia
# /wiki/Wikipedia:Wikipedia_Weekly
# /wiki/Wikipedia:BUGLE
# /wiki/Wikipedia:Milhist
# /wiki/Wikipedia:GOCE
# http://blog.wikimedia.org/
# https://outreach.wikimedia.org/wiki/This_Month_in_Education
# /wiki/GNU_Free_Documentation_License
# /wiki/Copyleft
# #cite_note-WP_copyright_and_commerciality_1-281
# /wiki/Free_software
# /wiki/GPL
# /wiki/Creative_Commons_license
# #cite_note-WPF_switch_to_CC-282
# /wiki/Free_Software_Foundation
# /wiki/Wikipedia:Licensing_update
# #cite_note-voteresult-283
# #cite_note-MW_licensing_QA-284
# #cite_note-MW_licensing_timeline_1-285
# #cite_note-WP_blog_license_migration-286
# /wiki/Fair_use
# /wiki/Copyright_law_of_Japan
# /wiki/Free_content
# /wiki/Creative_Commons
# /wiki/Wikimedia_Commons
# #cite_note-NYT_photos_on_WP-287
# #cite_note-reuters_French_defamation_case-288
# #cite_note-ars_tech_WP_dumb_suing_case-289
# /wiki/Mirror_website
# /wiki/Reference.com
# /wiki/Answers.com
# /wiki/Wapedia
# /wiki/Hand-held_device
# /wiki/Android_(operating_system)
# /wiki/IOS
# /wiki/Wikipedia_App
# #Mobile_access
# /wiki/Web_search_engine
# /wiki/Bing_(search_engine)
# /wiki/Powerset_(company)
# #cite_note-bing_WP_research_and_referencing-290
# /wiki/DuckDuckGo
# /wiki/Optical_disc
# /wiki/Wikipedia_CD_Selection
# #cite_note-wikipediaondvd_authorized_1-291
# #cite_note-wikipediaondvd_commercially_available_1-292
# #cite_note-WM_polish_WP_on_dvd-293
# #cite_note-WP_german_on_dvd_1-294
# #cite_note-python.org_CDPedia_Argentina_1-295
# /wiki/SOS_Children%27s_Villages_UK
# /wiki/National_Curriculum_(UK)
# #cite_note-WP_CD_selection_1-296
# #cite_note-WP_into_books_1-297
# #cite_note-WP_schools_selection_1-298
# /wiki/Print_on_demand
# /wiki/Books_LLC
# /wiki/Mauritius
# /wiki/VDM_Publishing
# #cite_note-FAZ-299
# /wiki/DBpedia
# /wiki/Wikidata
# /wiki/Semantic_Web
# /wiki/Resource_Description_Framework
# /wiki/Web_crawler
# #cite_note-WP_DB_usage_policy_1-300
# /wiki/Wikipedia:Database_download
# //en.wikipedia.org/w/index.php?title=Wikipedia&action=edit
# #cite_note-WP_image_data_dumps_1-301
# /wiki/Wikipedia:REFDESK
# /wiki/Journal_of_Documentation
# /wiki/Library_reference_desk
# #cite_note-slis_WP_reference_desk_1-302
# /wiki/Help:Mobile_access
# /wiki/File:En_Wikipedia_front_page_on_Firefox_49,_Android_4.2.2.png
# /wiki/File:En_Wikipedia_front_page_on_Firefox_49,_Android_4.2.2.png
# /wiki/Web_browser
# /wiki/Internet_access
# /wiki/Mobile_web
# #cite_note-small_screen-21
# #cite_note-small_screen-21
# #cite_note-small_screen-21
# /wiki/Bloomberg_Businessweek
# #cite_note-303
# /wiki/Sue_Gardner
# #cite_note-nytimes.com-241
# #cite_note-304
# #cite_note-305
# /wiki/Wireless_Application_Protocol
# /wiki/Wapedia
# http://en.mobile.wikipedia.org/
# #cite_note-WM_mobile_added_1-306
# https://en.m.wikipedia.org/
# /wiki/IPhone
# /wiki/Android_(operating_system)
# /wiki/WebOS
# /wiki/Metadata
# /wiki/Wikipedia:Metadata
# /wiki/Geoinformation
# #cite_note-androgeoid.com_LPOI_WP_1-307
# #cite_note-ilounge_iphone_gems_WP-308
# /wiki/Wikipedia_Zero
# #cite_note-309
# /wiki/Andrew_Lih
# /wiki/Andrew_Brown_(writer)
# /wiki/Smart_phone
# /wiki/MIT_Technology_Review
# /wiki/Wikipedian
# /wiki/Status_quo
# #cite_note-Simonite-2013-55
# #cite_note-310
# #cite_note-311
# #cite_note-small_screen-21
# /wiki/Logistic_function
# #cite_note-modelling-312
# #cite_note-comscore-313
# #cite_note-hitwisegoogle-314
# #cite_note-hitwiseAcademic-315
# #cite_note-365M-316
# /wiki/Pew_Research_Center
# #cite_note-Wikipedia_users-317
# #cite_note-318
# #cite_note-319
# /wiki/Wikipedia_in_culture
# /wiki/File:Wikipedia_Monument_in_S%C5%82ubice_-_detail.JPG
# /wiki/File:Wikipedia_Monument_in_S%C5%82ubice_-_detail.JPG
# /wiki/Wikipedia_Monument
# /wiki/S%C5%82ubice
# #cite_note-Wikipedia_in_media-320
# #cite_note-Bourgeois-321
# #cite_note-ssrn.com_Wikipedian_Justice_1-322
# /wiki/Parliament_of_Canada
# /wiki/Same-sex_marriage
# /wiki/Civil_Marriage_Act
# #cite_note-parl.gc.ca_same-sex_marriage-323
# /wiki/World_Intellectual_Property_Organization
# #cite_note-WP_court_source-324
# #cite_note-Courts_turn_to_Wikipedia-325
# /wiki/United_States_Intelligence_Community
# #cite_note-US_Intelligence-326
# /wiki/RNA_Biology
# /wiki/Rfam
# #cite_note-Declan-327
# #cite_note-ajr.org_WP_in_the_newsroom-328
# #cite_note-twsY23-329
# #cite_note-shizuoka_plagiarized_WP_1-330
# #cite_note-WA_Express-News_staffer_resigns-331
# #cite_note-starbulletin.com_Inquiry_prompts_dismissal-332
# /wiki/Time_(magazine)
# /wiki/YouTube
# /wiki/Reddit
# /wiki/MySpace
# /wiki/Facebook
# #cite_note-Time2006-333
# /wiki/BBC_Radio_4
# #cite_note-334
# /wiki/Google
# /wiki/Italy
# /wiki/Franco_Grillini
# /wiki/Freedom_of_panorama
# #cite_note-335
# //upload.wikimedia.org/wikipedia/commons/3/33/Wikipedia%2C_an_introduction_-_Erasmus_Prize_2015.webm
# /wiki/File:Wikipedia,_an_introduction_-_Erasmus_Prize_2015.webm
# /wiki/Erasmus_Prize
# /wiki/File:Quadriga-verleihung-rr-02.jpg
# /wiki/File:Quadriga-verleihung-rr-02.jpg
# /wiki/Jimmy_Wales
# /wiki/Quadriga_(award)
# /wiki/The_Washington_Post
# /wiki/United_States_presidential_election,_2008
# #cite_note-WP.com_WP_election_usage-336
# /wiki/Reuters
# #cite_note-337
# #cite_note-LER_students_write_for_WP_1-338
# /wiki/Peter_Stone_(professor)
# /wiki/Stanford
# /wiki/One_Hundred_Year_Study_on_Artificial_Intelligence
# #cite_note-339
# /wiki/File:Wikipedia_team_visiting_to_Parliament_of_Oviedo_Spain_2015.JPG
# /wiki/File:Wikipedia_team_visiting_to_Parliament_of_Oviedo_Spain_2015.JPG
# /wiki/File:Spain_wikipedians_photo.JPG
# /wiki/File:Spain_wikipedians_photo.JPG
# #cite_note-WP_awards_for_WP_1-340
# /wiki/Prix_Ars_Electronica
# /wiki/Austria
# /wiki/Webby_Award
# #cite_note-webbyawards_WP_awards_1-341
# #cite_note-brandchannel.com_awards_1-342
# /wiki/Quadriga_(award)
# /wiki/Boris_Tadi%C4%87
# /wiki/Eckart_H%C3%B6fling
# /wiki/Peter_Gabriel
# /wiki/David_Weinberger
# #cite_note-loomarea.com_WP_award_1-343
# /wiki/Erasmus_Prize
# #cite_note-EP2015-344
# /wiki/Spain
# /wiki/Princess_of_Asturias_Award
# #cite_note-345
# /wiki/Jimmy_Wales
# /wiki/Asturian_language
# #cite_note-346
# /wiki/Asturian_Wikipedia
# /wiki/Category:Parodies_of_Wikipedia
# /wiki/Stephen_Colbert
# /wiki/The_Colbert_Report
# /wiki/Wikiality
# #cite_note-wikiality-185
# /wiki/The_Onion
# #cite_note-onion_WP_750_years_1-347
# #cite_note-348
# /wiki/The_Office_(U.S._TV_series)
# /wiki/Michael_Scott_(The_Office)
# /wiki/Negotiation
# #cite_note-349
# #cite_note-350
# /wiki/My_Number_One_Doctor
# /wiki/Scrubs_(TV_series)
# /wiki/Perry_Cox
# /wiki/Raw_food_diet
# /wiki/Bone_cancer
# /wiki/List_of_Battlestar_Galactica_(2004_TV_series)_episodes
# #cite_note-Bakken_one_doctor_1-351
# /wiki/CollegeHumor
# #cite_note-collegehumor.com_WP_funny_1-352
# /wiki/Dilbert
# #cite_note-dilbert_WP_funny_1-353
# /wiki/BBC_Radio_4
# /wiki/Bigipedia
# #cite_note-comedy.org.uk_WP_funny_1-354
# /wiki/Tosh.0
# #cite_note-tosh_CC_WP_funny_1-355
# #cite_note-tosh_CC_WP_funny_2-356
# /wiki/The_New_Yorker
# /wiki/Website
# /wiki/Chelsea_Manning
# #cite_note-357
# /wiki/John_Julius_Norwich
# /wiki/The_Times
# #cite_note-358
# #cite_note-359
# /wiki/Wikimedia_project
# /wiki/Wikimedia_Foundation
# /wiki/Wikimedia_projects
# /wiki/Wiktionary
# #cite_note-WM_dictionary_1-360
# /wiki/Wikiquote
# /wiki/Wikibooks
# /wiki/Wikimedia_Commons
# /wiki/Wikinews
# /wiki/Wikiversity
# #cite_note-OurProjects-361
# /wiki/Wikispecies
# /wiki/Wikivoyage
# /wiki/Wikidata
# /wiki/File:WikiMedia_DC_2013_Annual_Meeting_08.JPG
# /wiki/File:WikiMedia_DC_2013_Annual_Meeting_08.JPG
# http://wikimediadc.org/wiki/Home
# /wiki/Encyclop%C3%A6dia_Britannica
# #cite_note-362
# #cite_note-363
# #cite_note-FT_impact_on_traditional_media-364
# /wiki/Nicholas_G._Carr
# /wiki/Web_2.0
# /wiki/User-generated_content
# #cite_note-RType_WP_traditional_media_impact_1-365
# /wiki/Chris_Anderson_(writer)
# /wiki/Wired_(magazine)
# /wiki/Nature_(journal)
# /wiki/Wisdom_of_crowds
# /wiki/Scientific_journal
# /wiki/Peer_review
# #cite_note-nature.com_crowds_wisdom-366
# /wiki/Kathryn_Hughes
# #cite_note-367
# /wiki/Text_corpus
# /wiki/Computational_linguistics
# /wiki/Information_retrieval
# /wiki/Natural_language_processing
# /wiki/Entity_linking
# #cite_note-wikify-368
# /wiki/Word_sense_disambiguation
# #cite_note-milne_witten_WP_usage_1-369
# #cite_note-discovering_missing_WP_links_1-370
# /wiki/University_of_Franche-Comt%C3%A9
# /wiki/Besan%C3%A7on
# /wiki/Paul_Sabatier_University
# /wiki/Toulouse
# #cite_note-mitmining-371
# #cite_note-harvardisonlymarmow-372
# #cite_note-wikipediarankingtimesworldunifranche-373
# /wiki/PageRank
# #cite_note-wikipediarankingtimesworldunifranche-373
# /wiki/BBC_Domesday_Project
# /wiki/BBC_Micro
# #cite_note-Domesday_Project-374
# /wiki/Everything2
# #cite_note-375
# /wiki/GNE_(encyclopedia)
# #cite_note-gnu.org-376
# /wiki/H2g2
# /wiki/Douglas_Adams
# /wiki/Knowledge_base
# /wiki/Susning.nu
# /wiki/Enciclopedia_Libre_Universal_en_Espa%C3%B1ol
# /wiki/Hudong
# /wiki/Baidu_Baike
# /wiki/Conservapedia
# /wiki/Peer_review
# /wiki/Encyclopedia_of_Life
# /wiki/Scholarpedia
# /wiki/Citizendium
# #cite_note-Orlowski18-377
# #cite_note-JayLyman-378
# /wiki/File:Crystal_Clear_app_linneighborhood.svg
# /wiki/Portal:Internet
# /wiki/Outline_of_Wikipedia
# /wiki/Tree_structure
# /wiki/Portal:Contents/Outlines
# /wiki/Conflict-of-interest_editing_on_Wikipedia
# /wiki/Democratization_of_knowledge
# /wiki/Interpedia
# /wiki/Internet
# /wiki/List_of_Internet_encyclopedias
# /wiki/Network_effect
# /wiki/Print_Wikipedia
# /wiki/QRpedia
# /wiki/Wikipedia_Review
# #cite_ref-Sidener_2-0
# https://web.archive.org/web/20160114101809/http://www.sandiegouniontribune.com/uniontrib/20041206/news_mz1b6encyclo.html
# /wiki/U-T_San_Diego
# http://www.signonsandiego.com/uniontrib/20041206/news_mz1b6encyclo.html
# #cite_ref-roadchap_5-0
# https://web.archive.org/web/20130922015103/http://rogchap.com/2011/09/06/top-40-website-programming-languages/
# /wiki/Category:CS1_maint:_Unfit_url
# #cite_ref-6
# http://www.theverge.com/2015/9/4/9260981/jimmy-wales-wikipedia-china
# #cite_ref-Tancer_7-0
# http://www.time.com/time/business/article/0,8599,1595184,00.html
# /wiki/Time_(magazine)
# /wiki/Cf.
# http://weblogs.hitwise.com/bill-tancer/2007/03/wikipedia_search_and_school_ho.html
# https://web.archive.org/web/20120325220239/http://weblogs.hitwise.com/bill-tancer/2007/03/wikipedia_search_and_school_ho.html
# /wiki/Wayback_Machine
# /wiki/Hitwise
# #cite_ref-Woodson_8-0
# http://www.reuters.com/article/internetNews/idUSN0819429120070708
# #cite_ref-9
# http://www.comscore.com/Insights/Press_Releases/2012/9/comScore_Media_Metrix_Ranks_Top_50_US_Web_Properties_for_August_201
# #cite_ref-Alexa_siteinfo_10-0
# #cite_ref-Alexa_siteinfo_10-1
# #cite_ref-Alexa_siteinfo_10-2
# http://www.alexa.com/siteinfo/wikipedia.org
# /wiki/Alexa_Internet
# #cite_ref-11
# http://www.bbc.com/news/10104946
# #cite_ref-12
# http://www.ecommercetimes.com/story/76351.html
# #cite_ref-13
# http://arstechnica.com/tech-policy/2014/01/wikimedia-foundation-employee-ousted-over-paid-editing/
# #cite_ref-KockJungSyn2016_14-0
# #cite_ref-KockJungSyn2016_14-1
# http://cits.tamiu.edu/kock/pubs/journals/2016JournalIJeC_WikipediaEcollaboration/Kock_etal_2016_IJeC_WikipediaEcollaboration.pdf
# https://web.archive.org/web/20160927001627/http://cits.tamiu.edu/kock/pubs/journals/2016JournalIJeC_WikipediaEcollaboration/Kock_etal_2016_IJeC_WikipediaEcollaboration.pdf
# /wiki/Wayback_Machine
# #cite_ref-MiliardWho_15-0
# http://www.cityweekly.net/utah/article-5129-feature-wikipediots-who-are-these-devoted-even-obsessive-contributors-to-wikipedia.html
# /wiki/Salt_Lake_City_Weekly
# #cite_ref-J_Sidener_16-0
# https://web.archive.org/web/20161111074945/http://legacy.sandiegouniontribune.com/news/tech/personaltech/20061009-9999-mz1b9wikiped.html
# /wiki/The_San_Diego_Union-Tribune
# http://legacy.utsandiego.com/news/tech/personaltech/20061009-9999-mz1b9wikiped.html
# #cite_ref-17
# #cite_ref-CBS_20-0
# http://www.cbsnews.com/news/wikipedia-jimmy-wales-morley-safer-60-minutes/
# /wiki/CBS_News
# #cite_ref-small_screen_21-0
# #cite_ref-small_screen_21-1
# #cite_ref-small_screen_21-2
# #cite_ref-small_screen_21-3
# #cite_ref-small_screen_21-4
# #cite_ref-small_screen_21-5
# https://www.nytimes.com/2014/02/10/technology/wikipedia-vs-the-small-screen.html?_r=0
# #cite_ref-FMonday_feat_article_patterns_2_22-0
# http://firstmonday.org/htbin/cgiwrap/bin/ojs/index.php/fm/article/view/2365/2182
# /wiki/First_Monday_(journal)
# #cite_ref-IBM_feat_articles_hidden_pattern_2_23-0
# http://www.research.ibm.com/visual/papers/hidden_order_wikipedia.pdf
# #cite_ref-GilesJ2005Internet_24-0
# #cite_ref-GilesJ2005Internet_24-1
# /wiki/Jim_Giles_(reporter)
# http://www.nature.com/nature/journal/v438/n7070/full/438900a.html
# /wiki/Nature_(journal)
# /wiki/Bibcode
# http://adsabs.harvard.edu/abs/2005Natur.438..900G
# /wiki/Digital_object_identifier
# //doi.org/10.1038%2F438900a
# /wiki/PubMed_Identifier
# //www.ncbi.nlm.nih.gov/pubmed/16355180
# http://news.bbc.co.uk/2/hi/technology/4530930.stm
# #cite_ref-EdwinBlack_25-0
# #cite_ref-EdwinBlack_25-1
# #cite_ref-EdwinBlack_25-2
# /wiki/Edwin_Black
# http://historynewsnetwork.org/article/125437
# https://web.archive.org/web/20160909210831/http://historynewsnetwork.org/article/125437
# /wiki/Wayback_Machine
# /wiki/History_News_Network
# #cite_ref-Petrilli_26-0
# #cite_ref-Petrilli_26-1
# http://educationnext.org/wikipedia-or-wickedpedia/
# https://web.archive.org/web/20161121024654/http://educationnext.org/wikipedia-or-wickedpedia/
# /wiki/Wayback_Machine
# /wiki/Education_Next
# #cite_ref-27
# http://www.niemanlab.org/2011/10/the-contribution-conundrum-why-did-wikipedia-succeed-while-other-encyclopedias-failed/
# #cite_ref-stallman1999_28-0
# /wiki/Richard_Stallman
# https://www.gnu.org/encyclopedia/encyclopedia.html
# #cite_ref-autogenerated1_29-0
# https://web.archive.org/web/20071011150228/http://signonsandiego.com/uniontrib/20041206/news_mz1b6encyclo.html
# /wiki/U-T_San_Diego
# http://www.signonsandiego.com/uniontrib/20041206/news_mz1b6encyclo.html
# #cite_ref-Meyers_30-0
# http://query.nytimes.com/gst/fullpage.html?res=9800E5D6123BF933A1575AC0A9679C8B63&n=Top%2fReference%2fTimes%20Topics%2fSubjects%2fC%2fComputer%20Software
# #cite_ref-SangerMemoir_31-0
# #cite_ref-SangerMemoir_31-1
# #cite_ref-SangerMemoir_31-2
# http://features.slashdot.org/features/05/04/18/164213.shtml
# #cite_ref-Sanger_32-0
# https://web.archive.org/web/20010506042824/http://www.nupedia.com/pipermail/nupedia-l/2001-January/000684.html
# http://www.nupedia.com/pipermail/nupedia-l/2001-January/000684.html
# #cite_ref-WM_foundation_of_WP_1_33-0
# http://lists.wikimedia.org/pipermail/wikipedia-l/2001-October/000671.html
# #cite_ref-nupedia_feeder_from_WP_1_34-0
# https://web.archive.org/web/20030414014355/http://www.nupedia.com/pipermail/nupedia-l/2001-January/000676.html
# http://www.nupedia.com/pipermail/nupedia-l/2001-January/000676.html
# #cite_ref-WikipediaHome_35-0
# https://web.archive.org/web/20010331173908/http://www.wikipedia.com/
# http://www.wikipedia.com/
# #cite_ref-NPOV_36-0
# /wiki/Wikipedia:Neutral
# #cite_ref-Seth-Finkelstein_37-0
# https://www.theguardian.com/technology/2008/sep/25/wikipedia.internet
# /wiki/The_Guardian
# #cite_ref-Wikipedia_August_08.2C_2001_38-0
# https://web.archive.org/web/20010727112808/http://www.wikipedia.org/
# http://www.wikipedia.org/
# #cite_ref-Wikipedia_September_25.2C_2001_39-0
# https://web.archive.org/web/20010331173908/http://www.wikipedia.com/
# http://www.wikipedia.com/
# #cite_ref-WP_early_language_stats_1_40-0
# https://en.wikipedia.org/wiki/Wikipedia:Multilingual_statistics
# #cite_ref-EB_encyclopedia_41-0
# #cite_ref-EL_fears_and_start_1_42-0
# http://osdir.com/ml/science.linguistics.wikipedia.international/2003-03/msg00008.html
# #cite_ref-Shirky_43-0
# /wiki/Clay_Shirky
# http://www.amazon.com/gp/reader/1594201536/ref=sib_dp_srch_pop?v=search-inside&keywords=spanish&go.x=0&go.y=0&go=Go%21
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources
# /wiki/Digital_object_identifier
# //doi.org/10.1177%2F1461444812470428
# #cite_ref-theatlantic_WP_actually_a_reversion_1_65-0
# https://www.theatlantic.com/technology/archive/2013/01/what-if-the-great-wikipedia-revolution-was-actually-a-reversion/272697
# #cite_ref-economictimes.indiatimes.com_66-0
# #cite_ref-economictimes.indiatimes.com_66-1
# #cite_ref-economictimes.indiatimes.com_66-2
# http://economictimes.indiatimes.com/articleshow/29094246.cms
# /wiki/Times_Internet_Limited
# #cite_ref-Alexa_67-0
# http://www.alexa.com/topsites
# /wiki/Alexa_Internet
# #cite_ref-stats.wikimedia_68-0
# #cite_ref-stats.wikimedia_68-1
# http://stats.wikimedia.org/EN/TablesWikipediaEN.htm
# #cite_ref-zittrain_70-0
# #cite_ref-zittrain_70-1
# /wiki/Jonathan_Zittrain
# https://web.archive.org/web/20090216015857/http://yupnet.org/zittrain/archives/16
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/978-0-300-12487-3
# http://yupnet.org/zittrain/archives/16
# #cite_ref-71
# /wiki/Wikipedia:Tutorial/Registration
# #cite_ref-WP_protection_policy_1_72-0
# /wiki/Wikipedia:Protection_policy
# #cite_ref-73
# https://www.nytimes.com/2006/06/17/technology/17wiki.html
# #cite_ref-74
# /wiki/Wikipedia:Protection_policy
# #cite_ref-75
# /wiki/Wikipedia:Full_protection
# #cite_ref-WP_some_sites_stable_versions_1_76-0
# #cite_ref-WP_some_sites_stable_versions_1_76-1
# http://lists.wikimedia.org/pipermail/wikide-l/2008-December/021594.html
# #cite_ref-BInsider_pending_changes_intro_1_77-0
# http://www.businessinsider.com/pending-changes-safeguard-on-wikipedia-2012-12
# #cite_ref-78
# http://www.bbc.com/news/10312095
# #cite_ref-Torsten_Kleinz_80-0
# #cite_ref-Torsten_Kleinz_80-1
# http://w3.linux-magazine.com/issue/51/Wikipedia_Encyclopedia.pdf
# #cite_ref-81
# /wiki/Wikipedia:New_pages_patrol
# #cite_ref-FMonday_collaborative_effort_1_82-0
# http://firstmonday.org/article/view/1108/1028
# https://web.archive.org/web/20161206104747/http://firstmonday.org/article/view/1108/1028
# /wiki/Wayback_Machine
# /wiki/First_Monday_(journal)
# #cite_ref-upenn_link_spamming_1_83-0
# http://repository.upenn.edu/cgi/viewcontent.cgi?article=1508&context=cis_papers
# /wiki/Digital_object_identifier
# //doi.org/10.1145%2F2030376.2030394
# #cite_ref-WP_vandalism_manipulation_1_84-0
# /wiki/Wikipedia:Vandalism
# #cite_ref-MIT_IBM_study_85-0
# https://web.archive.org/web/20060125025047/http://alumni.media.mit.edu/~fviegas/papers/history_flow.pdf
# /wiki/CHI_(conference)
# /wiki/SIGCHI
# /wiki/Digital_object_identifier
# //doi.org/10.1145%2F985921.985953
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/1-58113-702-8
# http://alumni.media.mit.edu/~fviegas/papers/history_flow.pdf
# #cite_ref-CreatingDestroyingAndRestoringValue_86-0
# http://www-users.cs.umn.edu/~reid/papers/group282-priedhorsky.pdf
# /wiki/Association_for_Computing_Machinery
# /wiki/University_of_Minnesota
# /wiki/Sanibel_Island
# /wiki/Florida
# #cite_ref-Seigenthaler_87-0
# #cite_ref-Seigenthaler_87-1
# #cite_ref-Seigenthaler_87-2
# #cite_ref-Seigenthaler_87-3
# http://www.usatoday.com/news/opinion/editorials/2005-11-29-wikipedia-edit_x.htm
# #cite_ref-book_The_World_is_Flat_1_88-0
# /wiki/Farrar,_Straus_%26_Giroux
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/978-0-374-29278-2
# #cite_ref-89
# https://web.archive.org/web/20121221140311/http://archive.firstamendmentcenter.org/news.aspx?id=17798
# http://archive.firstamendmentcenter.org/news.aspx?id=17798
# #cite_ref-90
# https://web.archive.org/web/20120708062333/http://www.businessweek.com/stories/2005-12-13/wikipedia-a-work-in-progress
# /wiki/BusinessWeek
# http://www.businessweek.com/stories/2005-12-13/wikipedia-a-work-in-progress
# #cite_ref-pcworld_who.27s_behind_WP_91-0
# https://web.archive.org/web/20080209110303/http://www.pcworld.idg.com.au/index.php/id%3B1866322157%3Bfp%3B2%3Bfpid%3B2
# http://www.pcworld.idg.com.au/index.php/id;1866322157;fp;2;fpid;2
# #cite_ref-WP_content_policy_1_92-0
# /wiki/Wikipedia:What_Wikipedia_is_not
# #cite_ref-WP_notability_guide_1_93-0
# /wiki/Wikipedia:Notability
# #cite_ref-NOR_94-0
# /wiki/Wikipedia:No_original_research
# #cite_ref-WP_Verifiability_policy_1_95-0
# /wiki/Wikipedia:Verifiability
# #cite_ref-IHT_WP_valid_info_wrong_removable_1_96-0
# https://archive.is/20140311231259/http://news-business.vlex.com/vid/inclusive-mission-is-that-goes-far-425135170
# /wiki/International_Herald_Tribune
# http://news-business.vlex.com/vid/inclusive-mission-is-that-goes-far-425135170
# #cite_ref-autogenerated2_97-0
# /wiki/Wikipedia:Neutral_point_of_view
# #cite_ref-alternet_WP_unethical_editing_destroy.27s_credibility_1_98-0
# http://www.alternet.org/story/61365/?page=entire
# #cite_ref-99
# http://features.slashdot.org/story/05/04/18/164213/the-early-history-of-nupedia-and-wikipedia-a-memoir
# #cite_ref-100
# http://firstmonday.org/ojs/index.php/fm/article/view/2613/2479
# #cite_ref-101
# /wiki/Wikipedia:Ownership_of_articles
# #cite_ref-102
# #cite_ref-103
# /wiki/Wikipedia:Administrators
# #cite_ref-David_Mehegan_104-0
# http://www.boston.com/business/technology/articles/2006/02/13/many_contributors_common_cause
# #cite_ref-105
# https://en.wikipedia.org/wiki/Wikipedia:Administrators#Administrator_conduct
# #cite_ref-106
# https://en.wikipedia.org/wiki/Wikipedia:RfA_Review/Reflect
# #cite_ref-107
# https://www.theatlantic.com/technology/archive/2012/07/3-charts-that-show-how-wikipedia-is-running-out-of-admins/259829
# /wiki/The_Atlantic
# #cite_ref-108
# /wiki/Wikipedia:Dispute_Resolution
# #cite_ref-NBC_WP_editorial_warzone_1_109-0
# http://sys03-public.nbcnews.com/technology/wikipedia-editorial-warzone-says-study-838793
# /wiki/NBC_News
# #cite_ref-emory_disputes_handled_1_111-0
# /wiki/Help:CS1_errors#format_missing_url
# /wiki/Emory_University_School_of_Law
# /wiki/Social_Science_Research_Network
# //ssrn.com/abstract=1354424
# #cite_ref-112
# /wiki/Emory_Law_Journal
# ...
# https://bm.wikipedia.org/wiki/Wikipedi
# https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%87%E0%A6%95%E0%A6%BF%E0%A6%AA%E0%A6%BF%E0%A6%A1%E0%A6%BF%E0%A6%AF%E0%A6%BC%E0%A6%B
wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D0%B0
# https://chr.wikipedia.org/wiki/%E1%8F%AB%E1%8E%A9%E1%8F%87%E1%8F%97%E1%8F%AF
# https://chy.wikipedia.org/wiki/Vekepete%27a
# https://ve.wikipedia.org/wiki/Wikipedia
# https://tr.wikipedia.org/wiki/Vikipedi
# https://tk.wikipedia.org/wiki/Wikipedi%C3%BDa
# https://tw.wikipedia.org/wiki/Wikipedia
# https://tyv.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F
# https://udm.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F
# https://bug.wikipedia.org/wiki/Wikipedia
# https://uk.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96%D0%BF%D0%B5%D0%B4%D1%96%D1%8F
# https://ur.wikipedia.org/wiki/%D9%88%DB%8C%DA%A9%DB%8C%D9%BE%DB%8C%DA%88%DB%8C%D8%A7
# https://ug.wikipedia.org/wiki/%DB%8B%D9%89%D9%83%D9%89%D9%BE%DB%90%D8%AF%D9%89%D9%8A%DB%95
# https://za.wikipedia.org/wiki/Veizgiek_Bakgoh
# https://vec.wikipedia.org/wiki/Wikipedia
# https://vep.wikipedia.org/wiki/Vikipedii
# https://vi.wikipedia.org/wiki/Wikipedia
# https://vo.wikipedia.org/wiki/V%C3%BCkiped
# https://fiu-vro.wikipedia.org/wiki/Vikipeedi%C3%A4
# https://wa.wikipedia.org/wiki/Wikipedia
# https://zh-classical.wikipedia.org/wiki/%E7%B6%AD%E5%9F%BA%E5%A4%A7%E5%85%B8
# https://vls.wikipedia.org/wiki/Wikipedia
# https://war.wikipedia.org/wiki/Wikipedia
# https://wo.wikipedia.org/wiki/Wikipedia
# https://wuu.wikipedia.org/wiki/%E7%BB%B4%E5%9F%BA%E7%99%BE%E7%A7%91
# https://ts.wikipedia.org/wiki/Wikipediya
# https://yi.wikipedia.org/wiki/%D7%95%D7%95%D7%99%D7%A7%D7%99%D7%A4%D7%A2%D7%93%D7%99%D7%A2
# https://yo.wikipedia.org/wiki/Wikipedia
# https://zh-yue.wikipedia.org/wiki/%E7%B6%AD%E5%9F%BA%E7%99%BE%E7%A7%91
# https://diq.wikipedia.org/wiki/Wikipediya
# https://zea.wikipedia.org/wiki/Wikipedia
# https://bat-smg.wikipedia.org/wiki/Vikiped%C4%97j%C4%97
# https://zh.wikipedia.org/wiki/%E7%BB%B4%E5%9F%BA%E7%99%BE%E7%A7%91
# https://dty.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A4%BF%E0%A4%AA%E0%A4%BF%E0%A4%A1%E0%A4%BF%E0%A4%AF%E0%A4%BE
# https://www.wikidata.org/wiki/Q52#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //wikimediafoundation.org/wiki/Terms_of_Use
# //wikimediafoundation.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://wikimediafoundation.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://wikimediafoundation.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Wikipedia&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# //www.mediawiki.org/

# %% [markdown]
# # 12.3 项目实施（深度优先的递归爬虫）

# %%
#!/usr/bin/python
# coding: utf-8

import requests
import re
import time

exist_url = []
news_ids = []
g_writecount = 0

def scrappy(url, depth = 1):
    global g_writecount    
    try:
        headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
        r = requests.get("https://en.wikipedia.org/wiki/" + url, headers= headers)
        html = r.text
    except Exception as e: 
        print ('Failed downloading and saving', url)
        print (e)
        exist_url.append(url)
        return None
    
    exist_url.append(url)
    link_list = re.findall('<a href="/wiki/([^:#=<>]*?)".*?</a>',html)
    unique_list = list(set(link_list) - set(exist_url))
    
    for eachone in unique_list:
        g_writecount += 1
        output = "No." + str(g_writecount) + "\t Depth:" +  str(depth) + "\t"+ url + ' -> ' + eachone + '\n'
        #print (output)
        with open('link_12-3.txt', "a+") as f:
            f.write(output)
            f.close()

        if depth < 2:
            scrappy(eachone, depth+1)

scrappy("Wikipedia")

# %% [markdown]
# # 12.4 项目进阶（广度优先的多线程爬虫）

# %%
#!/usr/bin/env python  
#coding=utf-8  
import threading  
import requests
import re  
import time  
g_mutex = threading.Condition()  
g_pages = [] #从中解析所有url链接  
g_queueURL = [] #等待爬取的url链接列表  
g_existURL = [] #已经爬取过的url链接列表    
g_writecount = 0 #找到的链接数

class Crawler:  
    def __init__(self,url,threadnum):   
        self.url=url  
        self.threadnum=threadnum  
        self.threadpool=[]   

    def craw(self):  #爬虫的控制大脑，包括爬取网页，更新队列
        global g_queueURL  
        g_queueURL.append(url)
        depth=1
        while(depth < 3):    
            print ('Searching depth ',depth,'...\n')  
            self.downloadAll()  
            self.updateQueueURL()
            g_pages = []
            depth += 1  

    def downloadAll(self): #调用多线程爬虫，在小于线程最大值和没爬完队列之前，会增加线程
        global g_queueURL    
        i=0  
        while i<len(g_queueURL):  
            j=0  
            while j<self.threadnum and i+j < len(g_queueURL):    
                threadresult = self.download(g_queueURL[i+j],j)    
                j+=1  
            i += j  
            for thread in self.threadpool:  
                thread.join(30)  
            threadpool=[]  
        g_queueURL=[]  

    def download(self,url,tid): #调用多线程爬虫 
        crawthread=CrawlerThread(url,tid)  
        self.threadpool.append(crawthread)  
        crawthread.start()  

    def updateQueueURL(self): #完成一个深度的爬虫之后，更新队列
        global g_queueURL  
        global g_existURL  
        newUrlList=[]  
        for content in g_pages:  
            newUrlList+=self.getUrl(content)  
        g_queueURL=list(set(newUrlList)-set(g_existURL))    

    def getUrl(self,content): #从获取的网页中解析url 
        link_list = re.findall('<a href="/wiki/([^:#=<>]*?)".*?</a>',content)
        unique_list = list(set(link_list)) 
        return unique_list  

class CrawlerThread(threading.Thread): #爬虫线程
    def __init__(self,url,tid):  
        threading.Thread.__init__(self)  
        self.url=url  
        self.tid=tid  
    def run(self):  
        global g_mutex    
        global g_writecount  
        try:
            print (self.tid, "crawl ", self.url)
            headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
            r = requests.get("https://en.wikipedia.org/wiki/" + self.url, headers= headers)
            html = r.text

            link_list2 = re.findall('<a href="/wiki/([^:#=<>]*?)".*?</a>',html)
            unique_list2 = list(set(link_list2))
            for eachone in unique_list2:
                g_writecount += 1
                content2 = "No." + str(g_writecount) + "\t Thread" +  str(self.tid) + "\t"+ self.url + '->' + eachone +'\n'
                with open('title2.txt', "a+") as f:
                    f.write(content2)
                    f.close()
        except Exception as e: 
            g_mutex.acquire()  
            g_existURL.append(self.url)   
            g_mutex.release()  
            print ('Failed downloading and saving',self.url)
            print (e)
            return None
        g_mutex.acquire()  
        g_pages.append(html)  
        g_existURL.append(self.url)  
        g_mutex.release()

if __name__ == "__main__":
    url = "Wikipedia"
    threadnum = 5
    crawler = Crawler(url,threadnum)  
    crawler.craw()
